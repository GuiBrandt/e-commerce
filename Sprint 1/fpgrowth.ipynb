# %% [markdown]
# # Análise de compras conjuntas por Frequent Pattern Growth (FPGrowth)

# %% [markdown]
# ## Importação de bibliotecas

# %%
from pyspark.ml.fpm import FPGrowth
from pyspark import SparkContext, SQLContext
from pyspark.sql import SparkSession

import pandas as pd

# %% [markdown]
# ## Leitura de dados
#
# De `all_orders.csv` obtemos os identificadores de consumidor, os quais podemos cruzar com os dados de `sold_products.csv`, obtendo uma lista de compras por cliente

# %%
all_orders = pd.read_csv('../datasets/trusted/all_orders.csv')
all_orders.count()
# Out:
# Unnamed: 0                       99441
# order_id                         99441
# customer_unique_id               99441
# customer_city                    99441
# customer_state                   99441
# order_approved_at                99281
# order_purchase_timestamp         99441
# order_estimated_delivery_date    99441
# order_delivered_carrier_date     97658
# order_delivered_customer_date    96476
# dtype: int64

# %%
sold_products = pd.read_csv('../datasets/trusted/sold_products.csv')
sold_products.count()
# Out:
# Unnamed: 0                       104881
# product_id                       104881
# order_id                         104881
# price                            104881
# freight_value                    104881
# order_purchase_timestamp         104881
# order_estimated_delivery_date    104881
# order_delivered_carrier_date     104881
# order_delivered_customer_date    104881
# product_category_name            104881
# product_name_lenght              104881
# product_description_lenght       104881
# product_photos_qty               104881
# product_weight_g                 104881
# product_length_cm                104881
# product_height_cm                104881
# product_width_cm                 104881
# dtype: int64

# %%
sales_by_category = all_orders[['order_id', 'customer_unique_id']].merge(sold_products[['order_id', 'product_category_name']], on='order_id')
sales_by_category.count()
# Out:
# order_id                 104881
# customer_unique_id       104881
# product_category_name    104881
# dtype: int64

# %%
customers_with_many_cats = sales_by_category.groupby('customer_unique_id').agg('count')['product_category_name']
customers_with_many_cats = customers_with_many_cats[customers_with_many_cats > 1]
customers_with_many_cats.head()
# Out:
# customer_unique_id
# 00053a61a98854899e70ed204dd4bafe    2
# 000de6019bb59f34c099a907c151d855    2
# 000fbf0473c10fc1ab6f8d2d286ce20c    4
# 001147e649a7b1afd577e873841632dd    2
# 0015752e079902b12cd00b9b7596276b    2
# Name: product_category_name, dtype: int64

# %%
sales_list = [list(sales_by_category[sales_by_category['customer_unique_id'] == user]['product_category_name'].unique()) for user in customers_with_many_cats.index]
sales_list
# Out:
# [['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['brinquedos', 'instrumentos_musicais'],
#  ['utilidades_domesticas'],
#  ['malas_acessorios'],
#  ['eletronicos', 'informatica_acessorios'],
#  ['moveis_sala', 'cama_mesa_banho'],
#  ['papelaria'],
#  ['beleza_saude'],
#  ['beleza_saude'],
#  ['malas_acessorios'],
#  ['beleza_saude'],
#  ['moveis_escritorio'],
#  ['cool_stuff', 'malas_acessorios'],
#  ['moveis_decoracao'],
#  ['moveis_escritorio'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['telefonia'],
#  ['ferramentas_jardim'],
#  ['brinquedos'],
#  ['esporte_lazer'],
#  ['utilidades_domesticas'],
#  ['utilidades_domesticas'],
#  ['flores', 'moveis_decoracao'],
#  ['esporte_lazer', 'eletronicos'],
#  ['bebes', 'moveis_decoracao'],
#  ['bebidas'],
#  ['beleza_saude'],
#  ['perfumaria'],
#  ['ferramentas_jardim'],
#  ['fashion_bolsas_e_acessorios'],
#  ['eletrodomesticos', 'cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['perfumaria'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['beleza_saude'],
#  ['ferramentas_jardim'],
#  ['utilidades_domesticas', 'cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['automotivo', 'ferramentas_jardim'],
#  ['instrumentos_musicais', 'brinquedos'],
#  ['automotivo'],
#  ['alimentos', 'esporte_lazer'],
#  ['beleza_saude', 'moveis_escritorio'],
#  ['automotivo'],
#  ['construcao_ferramentas_iluminacao', 'moveis_decoracao'],
#  ['esporte_lazer'],
#  ['moveis_cozinha_area_de_servico_jantar_e_jardim'],
#  ['ferramentas_jardim'],
#  ['brinquedos', 'instrumentos_musicais'],
#  ['esporte_lazer'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho', 'utilidades_domesticas'],
#  ['ferramentas_jardim'],
#  ['pet_shop'],
#  ['relogios_presentes'],
#  ['eletronicos'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['fashion_calcados'],
#  ['alimentos'],
#  ['beleza_saude'],
#  ['utilidades_domesticas'],
#  ['esporte_lazer'],
#  ['informatica_acessorios'],
#  ['relogios_presentes'],
#  ['relogios_presentes'],
#  ['automotivo'],
#  ['beleza_saude'],
#  ['moveis_escritorio'],
#  ['moveis_decoracao'],
#  ['fashion_bolsas_e_acessorios'],
#  ['telefonia_fixa'],
#  ['beleza_saude'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho', 'cool_stuff'],
#  ['esporte_lazer'],
#  ['papelaria'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['brinquedos'],
#  ['moveis_escritorio'],
#  ['moveis_decoracao'],
#  ['pet_shop'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['telefonia'],
#  ['informatica_acessorios', 'consoles_games'],
#  ['beleza_saude'],
#  ['automotivo'],
#  ['pet_shop'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['esporte_lazer', 'relogios_presentes'],
#  ['relogios_presentes'],
#  ['beleza_saude'],
#  ['moveis_sala', 'cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['eletronicos'],
#  ['beleza_saude'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios', 'dvds_blu_ray'],
#  ['beleza_saude', 'bebes'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['ferramentas_jardim'],
#  ['informatica_acessorios'],
#  ['eletronicos'],
#  ['construcao_ferramentas_ferramentas'],
#  ['pet_shop'],
#  ['consoles_games'],
#  ['esporte_lazer'],
#  ['telefonia_fixa', 'utilidades_domesticas'],
#  ['cama_mesa_banho', 'beleza_saude'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['moveis_escritorio'],
#  ['moveis_decoracao', 'cama_mesa_banho'],
#  ['pet_shop'],
#  ['bebes', 'esporte_lazer'],
#  ['brinquedos'],
#  ['eletrodomesticos'],
#  ['eletronicos', 'telefonia'],
#  ['relogios_presentes'],
#  ['utilidades_domesticas', 'moveis_decoracao'],
#  ['bebes', 'utilidades_domesticas'],
#  ['papelaria'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['telefonia'],
#  ['perfumaria'],
#  ['utilidades_domesticas', 'moveis_sala'],
#  ['pet_shop'],
#  ['moveis_decoracao'],
#  ['telefonia'],
#  ['papelaria'],
#  ['pet_shop'],
#  ['relogios_presentes'],
#  ['bebes'],
#  ['perfumaria', 'esporte_lazer'],
#  ['telefonia'],
#  ['ferramentas_jardim'],
#  ['automotivo'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho', 'casa_conforto'],
#  ['construcao_ferramentas_construcao', 'utilidades_domesticas'],
#  ['informatica_acessorios'],
#  ['telefonia'],
#  ['ferramentas_jardim'],
#  ['esporte_lazer'],
#  ['beleza_saude', 'eletroportateis'],
#  ['esporte_lazer'],
#  ['market_place'],
#  ['automotivo'],
#  ['telefonia'],
#  ['esporte_lazer'],
#  ['moveis_decoracao'],
#  ['beleza_saude'],
#  ['eletroportateis'],
#  ['bebidas', 'telefonia', 'automotivo'],
#  ['cama_mesa_banho'],
#  ['ferramentas_jardim'],
#  ['malas_acessorios'],
#  ['cama_mesa_banho'],
#  ['perfumaria'],
#  ['eletroportateis'],
#  ['construcao_ferramentas_construcao'],
#  ['esporte_lazer'],
#  ['artigos_de_natal'],
#  ['esporte_lazer'],
#  ['papelaria'],
#  ['bebes'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['sinalizacao_e_seguranca'],
#  ['brinquedos', 'cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['bebes'],
#  ['moveis_decoracao'],
#  ['brinquedos'],
#  ['esporte_lazer'],
#  ['brinquedos', 'papelaria'],
#  ['moveis_decoracao'],
#  ['moveis_escritorio'],
#  ['beleza_saude'],
#  ['bebes'],
#  ['cama_mesa_banho', 'ferramentas_jardim'],
#  ['audio'],
#  ['bebes', 'fashion_calcados'],
#  ['telefonia'],
#  ['utilidades_domesticas', 'cool_stuff'],
#  ['relogios_presentes', 'audio'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['eletrodomesticos'],
#  ['utilidades_domesticas'],
#  ['relogios_presentes'],
#  ['brinquedos'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao', 'utilidades_domesticas'],
#  ['beleza_saude'],
#  ['cama_mesa_banho'],
#  ['eletrodomesticos'],
#  ['cama_mesa_banho', 'moveis_decoracao'],
#  ['telefonia'],
#  ['moveis_decoracao'],
#  ['utilidades_domesticas'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['consoles_games'],
#  ['brinquedos'],
#  ['pet_shop'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['automotivo'],
#  ['cama_mesa_banho'],
#  ['bebidas'],
#  ['bebes', 'utilidades_domesticas'],
#  ['utilidades_domesticas'],
#  ['cama_mesa_banho', 'bebes'],
#  ['cama_mesa_banho'],
#  ['alimentos_bebidas'],
#  ['esporte_lazer', 'eletroportateis'],
#  ['esporte_lazer'],
#  ['eletronicos'],
#  ['perfumaria'],
#  ['utilidades_domesticas'],
#  ['perfumaria', 'moveis_decoracao'],
#  ['telefonia', 'informatica_acessorios'],
#  ['beleza_saude', 'perfumaria'],
#  ['informatica_acessorios'],
#  ['informatica_acessorios'],
#  ['esporte_lazer', 'brinquedos'],
#  ['informatica_acessorios'],
#  ['automotivo'],
#  ['informatica_acessorios'],
#  ['utilidades_domesticas'],
#  ['brinquedos'],
#  ['relogios_presentes'],
#  ['moveis_decoracao'],
#  ['construcao_ferramentas_construcao'],
#  ['telefonia'],
#  ['automotivo'],
#  ['relogios_presentes', 'ferramentas_jardim'],
#  ['automotivo'],
#  ['consoles_games'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['automotivo'],
#  ['moveis_decoracao'],
#  ['pet_shop'],
#  ['moveis_escritorio'],
#  ['fashion_bolsas_e_acessorios', 'esporte_lazer'],
#  ['utilidades_domesticas'],
#  ['perfumaria'],
#  ['eletrodomesticos'],
#  ['ferramentas_jardim'],
#  ['pet_shop'],
#  ['brinquedos'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['automotivo'],
#  ['eletrodomesticos', 'cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['cool_stuff'],
#  ['beleza_saude'],
#  ['telefonia'],
#  ['cama_mesa_banho'],
#  ['alimentos'],
#  ['moveis_decoracao'],
#  ['moveis_escritorio'],
#  ['construcao_ferramentas_construcao'],
#  ['eletrodomesticos'],
#  ['beleza_saude'],
#  ['perfumaria', 'climatizacao'],
#  ['esporte_lazer'],
#  ['relogios_presentes', 'cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['telefonia'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao', 'cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['beleza_saude'],
#  ['informatica_acessorios'],
#  ['eletronicos'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['telefonia', 'cine_foto', 'cool_stuff'],
#  ['utilidades_domesticas'],
#  ['brinquedos'],
#  ['cama_mesa_banho'],
#  ['casa_construcao'],
#  ['construcao_ferramentas_seguranca'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['fashion_bolsas_e_acessorios'],
#  ['cama_mesa_banho'],
#  ['moveis_sala'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['telefonia'],
#  ['ferramentas_jardim'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao', 'papelaria'],
#  ['consoles_games', 'esporte_lazer'],
#  ['fashion_bolsas_e_acessorios'],
#  ['relogios_presentes'],
#  ['cama_mesa_banho'],
#  ['eletrodomesticos', 'utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['beleza_saude'],
#  ['utilidades_domesticas'],
#  ['ferramentas_jardim'],
#  ['utilidades_domesticas'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['papelaria', 'ferramentas_jardim'],
#  ['relogios_presentes'],
#  ['esporte_lazer'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao', 'industria_comercio_e_negocios'],
#  ['informatica_acessorios'],
#  ['papelaria'],
#  ['utilidades_domesticas'],
#  ['papelaria'],
#  ['perfumaria', 'malas_acessorios', 'moveis_decoracao'],
#  ['consoles_games', 'utilidades_domesticas'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['ferramentas_jardim'],
#  ['automotivo'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['ferramentas_jardim'],
#  ['cool_stuff'],
#  ['telefonia'],
#  ['bebidas'],
#  ['ferramentas_jardim'],
#  ['bebes', 'cool_stuff'],
#  ['audio', 'relogios_presentes'],
#  ['beleza_saude'],
#  ['instrumentos_musicais'],
#  ['cama_mesa_banho', 'utilidades_domesticas'],
#  ['perfumaria'],
#  ['ferramentas_jardim'],
#  ['construcao_ferramentas_construcao'],
#  ['ferramentas_jardim'],
#  ['utilidades_domesticas'],
#  ['utilidades_domesticas', 'papelaria'],
#  ['utilidades_domesticas'],
#  ['esporte_lazer', 'beleza_saude'],
#  ['esporte_lazer'],
#  ['beleza_saude'],
#  ['cool_stuff', 'ferramentas_jardim'],
#  ['moveis_escritorio'],
#  ['relogios_presentes'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['perfumaria'],
#  ['esporte_lazer', 'moveis_decoracao'],
#  ['casa_construcao'],
#  ['utilidades_domesticas', 'esporte_lazer'],
#  ['utilidades_domesticas'],
#  ['cama_mesa_banho'],
#  ['relogios_presentes'],
#  ['moveis_decoracao'],
#  ['alimentos', 'perfumaria'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['utilidades_domesticas', 'esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['beleza_saude'],
#  ['esporte_lazer'],
#  ['perfumaria'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao', 'perfumaria'],
#  ['bebes', 'cama_mesa_banho'],
#  ['telefonia_fixa'],
#  ['esporte_lazer'],
#  ['utilidades_domesticas', 'eletroportateis'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho', 'moveis_sala'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['informatica_acessorios'],
#  ['informatica_acessorios'],
#  ['brinquedos'],
#  ['moveis_escritorio'],
#  ['beleza_saude'],
#  ['informatica_acessorios'],
#  ['papelaria'],
#  ['utilidades_domesticas'],
#  ['casa_conforto_2'],
#  ['consoles_games'],
#  ['esporte_lazer'],
#  ['informatica_acessorios'],
#  ['relogios_presentes'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['industria_comercio_e_negocios', 'moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['relogios_presentes'],
#  ['informatica_acessorios'],
#  ['fashion_bolsas_e_acessorios', 'brinquedos'],
#  ['construcao_ferramentas_construcao'],
#  ['cama_mesa_banho', 'brinquedos'],
#  ['pet_shop'],
#  ['papelaria'],
#  ['beleza_saude'],
#  ['cama_mesa_banho'],
#  ['ferramentas_jardim', 'utilidades_domesticas'],
#  ['market_place'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['relogios_presentes', 'moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['moveis_escritorio'],
#  ['ferramentas_jardim'],
#  ['utilidades_domesticas', 'cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['cool_stuff', 'fashion_bolsas_e_acessorios'],
#  ['esporte_lazer', 'construcao_ferramentas_construcao'],
#  ['cool_stuff'],
#  ['relogios_presentes'],
#  ['industria_comercio_e_negocios', 'beleza_saude'],
#  ['cama_mesa_banho', 'utilidades_domesticas'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['telefonia'],
#  ['ferramentas_jardim'],
#  ['bebes'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho', 'utilidades_domesticas'],
#  ['artigos_de_festas'],
#  ['papelaria'],
#  ['utilidades_domesticas'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['pet_shop'],
#  ['esporte_lazer'],
#  ['brinquedos', 'informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['papelaria'],
#  ['bebes'],
#  ['moveis_cozinha_area_de_servico_jantar_e_jardim', 'moveis_decoracao'],
#  ['esporte_lazer'],
#  ['perfumaria', 'brinquedos'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['telefonia'],
#  ['ferramentas_jardim'],
#  ['cool_stuff', 'consoles_games'],
#  ['ferramentas_jardim'],
#  ['utilidades_domesticas'],
#  ['automotivo'],
#  ['moveis_escritorio'],
#  ['livros_interesse_geral'],
#  ['telefonia'],
#  ['cama_mesa_banho'],
#  ['ferramentas_jardim'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['brinquedos'],
#  ['eletronicos', 'fashion_bolsas_e_acessorios'],
#  ['construcao_ferramentas_construcao'],
#  ['artes', 'ferramentas_jardim'],
#  ['informatica_acessorios'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho', 'cool_stuff'],
#  ['pet_shop', 'casa_construcao'],
#  ['informatica_acessorios'],
#  ['ferramentas_jardim'],
#  ['esporte_lazer', 'consoles_games'],
#  ['moveis_decoracao', 'bebes'],
#  ['informatica_acessorios'],
#  ['casa_construcao'],
#  ['pet_shop'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['perfumaria'],
#  ['brinquedos', 'esporte_lazer'],
#  ['beleza_saude'],
#  ['esporte_lazer'],
#  ['esporte_lazer'],
#  ['bebes'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer', 'beleza_saude'],
#  ['papelaria'],
#  ['ferramentas_jardim'],
#  ['cama_mesa_banho'],
#  ['livros_importados'],
#  ['utilidades_domesticas'],
#  ['construcao_ferramentas_construcao'],
#  ['moveis_decoracao'],
#  ['automotivo'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['ferramentas_jardim'],
#  ['moveis_decoracao', 'casa_construcao'],
#  ['ferramentas_jardim', 'esporte_lazer'],
#  ['informatica_acessorios'],
#  ['sinalizacao_e_seguranca'],
#  ['beleza_saude'],
#  ['cool_stuff'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas'],
#  ['automotivo', 'consoles_games'],
#  ['ferramentas_jardim'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['esporte_lazer', 'beleza_saude'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho', 'moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['perfumaria'],
#  ['moveis_decoracao', 'casa_conforto'],
#  ['telefonia_fixa'],
#  ['moveis_escritorio'],
#  ['beleza_saude'],
#  ['informatica_acessorios'],
#  ['moveis_escritorio'],
#  ['bebes'],
#  ['papelaria', 'casa_construcao'],
#  ['utilidades_domesticas'],
#  ['beleza_saude'],
#  ['telefonia'],
#  ['perfumaria'],
#  ['moveis_decoracao', 'construcao_ferramentas_construcao'],
#  ['moveis_escritorio'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['beleza_saude', 'utilidades_domesticas'],
#  ['beleza_saude'],
#  ['moveis_sala', 'brinquedos'],
#  ['moveis_decoracao'],
#  ['beleza_saude'],
#  ['utilidades_domesticas'],
#  ['utilidades_domesticas'],
#  ['utilidades_domesticas'],
#  ['esporte_lazer', 'telefonia', 'fashion_bolsas_e_acessorios'],
#  ['ferramentas_jardim', 'bebes', 'esporte_lazer'],
#  ['beleza_saude'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios', 'malas_acessorios'],
#  ['beleza_saude', 'cool_stuff'],
#  ['ferramentas_jardim'],
#  ['cama_mesa_banho'],
#  ['eletrodomesticos'],
#  ['moveis_decoracao'],
#  ['sinalizacao_e_seguranca'],
#  ['automotivo'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['eletroportateis', 'utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho', 'moveis_decoracao'],
#  ['relogios_presentes', 'casa_conforto'],
#  ['moveis_decoracao'],
#  ['perfumaria'],
#  ['malas_acessorios'],
#  ['esporte_lazer'],
#  ['brinquedos'],
#  ['casa_conforto', 'moveis_decoracao'],
#  ['utilidades_domesticas', 'perfumaria'],
#  ['utilidades_domesticas'],
#  ['cama_mesa_banho'],
#  ['artes', 'cool_stuff'],
#  ['brinquedos', 'consoles_games'],
#  ['relogios_presentes', 'livros_interesse_geral'],
#  ['esporte_lazer'],
#  ['moveis_sala'],
#  ['cama_mesa_banho'],
#  ['beleza_saude', 'cool_stuff'],
#  ['esporte_lazer'],
#  ['moveis_decoracao'],
#  ['malas_acessorios', 'telefonia'],
#  ['informatica_acessorios'],
#  ['informatica_acessorios', 'ferramentas_jardim'],
#  ['casa_construcao', 'ferramentas_jardim'],
#  ['esporte_lazer'],
#  ['ferramentas_jardim'],
#  ['cama_mesa_banho', 'bebidas'],
#  ['perfumaria'],
#  ['alimentos', 'esporte_lazer'],
#  ['beleza_saude'],
#  ['beleza_saude', 'alimentos'],
#  ['perfumaria'],
#  ['cama_mesa_banho'],
#  ['telefonia'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['construcao_ferramentas_construcao'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['automotivo', 'beleza_saude'],
#  ['pet_shop'],
#  ['livros_interesse_geral'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['esporte_lazer'],
#  ['ferramentas_jardim'],
#  ['esporte_lazer'],
#  ['moveis_decoracao'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['brinquedos', 'cool_stuff'],
#  ['bebes', 'cama_mesa_banho', 'fashion_bolsas_e_acessorios'],
#  ['ferramentas_jardim'],
#  ['cool_stuff'],
#  ['moveis_cozinha_area_de_servico_jantar_e_jardim'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['esporte_lazer'],
#  ['fashion_bolsas_e_acessorios'],
#  ['esporte_lazer'],
#  ['ferramentas_jardim'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas', 'automotivo'],
#  ['esporte_lazer'],
#  ['eletrodomesticos'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['eletronicos'],
#  ['moveis_decoracao'],
#  ['moveis_escritorio'],
#  ['esporte_lazer'],
#  ['beleza_saude'],
#  ['brinquedos'],
#  ['cool_stuff'],
#  ['perfumaria'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['eletronicos', 'moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['beleza_saude'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['perfumaria'],
#  ['cama_mesa_banho'],
#  ['bebes'],
#  ['informatica_acessorios'],
#  ['utilidades_domesticas'],
#  ['pet_shop'],
#  ['casa_construcao'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['brinquedos'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['cama_mesa_banho', 'malas_acessorios'],
#  ['instrumentos_musicais'],
#  ['esporte_lazer'],
#  ['moveis_decoracao'],
#  ['casa_construcao'],
#  ['cama_mesa_banho'],
#  ['ferramentas_jardim'],
#  ['moveis_escritorio'],
#  ['beleza_saude'],
#  ['esporte_lazer', 'construcao_ferramentas_ferramentas'],
#  ['moveis_escritorio'],
#  ['cama_mesa_banho', 'utilidades_domesticas'],
#  ['beleza_saude'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['esporte_lazer', 'alimentos_bebidas'],
#  ['cama_mesa_banho'],
#  ['construcao_ferramentas_seguranca'],
#  ['casa_construcao', 'esporte_lazer'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['papelaria'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao', 'brinquedos'],
#  ['automotivo'],
#  ['brinquedos'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['brinquedos', 'construcao_ferramentas_construcao'],
#  ['perfumaria'],
#  ['esporte_lazer', 'telefonia'],
#  ['telefonia', 'telefonia_fixa'],
#  ['eletronicos', 'automotivo'],
#  ['pet_shop'],
#  ['cama_mesa_banho', 'moveis_decoracao'],
#  ['cool_stuff', 'pc_gamer', 'pet_shop'],
#  ['moveis_decoracao'],
#  ['automotivo'],
#  ['moveis_decoracao'],
#  ['ferramentas_jardim'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer', 'bebes'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['ferramentas_jardim'],
#  ['moveis_decoracao'],
#  ['relogios_presentes'],
#  ['consoles_games'],
#  ['esporte_lazer'],
#  ['construcao_ferramentas_construcao'],
#  ['climatizacao'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios', 'moveis_decoracao'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['beleza_saude'],
#  ['moveis_decoracao'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['beleza_saude', 'utilidades_domesticas'],
#  ['alimentos'],
#  ['telefonia'],
#  ['bebes'],
#  ['moveis_decoracao'],
#  ['relogios_presentes'],
#  ['cama_mesa_banho', 'informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['telefonia'],
#  ['beleza_saude'],
#  ['utilidades_domesticas'],
#  ['ferramentas_jardim'],
#  ['cool_stuff'],
#  ['utilidades_domesticas'],
#  ['construcao_ferramentas_iluminacao', 'esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['telefonia'],
#  ['informatica_acessorios'],
#  ['eletrodomesticos'],
#  ['perfumaria'],
#  ['cama_mesa_banho'],
#  ['moveis_sala', 'bebes', 'moveis_decoracao'],
#  ['perfumaria'],
#  ['utilidades_domesticas'],
#  ['ferramentas_jardim'],
#  ['moveis_decoracao'],
#  ['agro_industria_e_comercio'],
#  ['pet_shop', 'fashion_bolsas_e_acessorios', 'moveis_quarto'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao', 'pet_shop'],
#  ['artigos_de_natal'],
#  ['esporte_lazer'],
#  ['utilidades_domesticas'],
#  ['ferramentas_jardim'],
#  ['relogios_presentes'],
#  ['eletronicos'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['telefonia'],
#  ['papelaria'],
#  ['beleza_saude'],
#  ['utilidades_domesticas'],
#  ['utilidades_domesticas'],
#  ['beleza_saude'],
#  ['ferramentas_jardim'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao', 'bebes'],
#  ['cama_mesa_banho'],
#  ['construcao_ferramentas_construcao'],
#  ['sinalizacao_e_seguranca'],
#  ['dvds_blu_ray'],
#  ['telefonia'],
#  ['esporte_lazer'],
#  ['moveis_escritorio'],
#  ['moveis_decoracao', 'fashion_roupa_masculina'],
#  ['fashion_roupa_masculina'],
#  ['fashion_bolsas_e_acessorios', 'malas_acessorios'],
#  ['relogios_presentes', 'construcao_ferramentas_construcao'],
#  ['moveis_decoracao'],
#  ['ferramentas_jardim', 'utilidades_domesticas'],
#  ['papelaria'],
#  ['cama_mesa_banho'],
#  ['casa_conforto', 'cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['construcao_ferramentas_iluminacao', 'ferramentas_jardim'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['artes'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas'],
#  ['utilidades_domesticas'],
#  ['ferramentas_jardim'],
#  ['cama_mesa_banho'],
#  ['cool_stuff'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['brinquedos'],
#  ['moveis_decoracao'],
#  ['moveis_escritorio'],
#  ['bebidas'],
#  ['esporte_lazer', 'relogios_presentes'],
#  ['esporte_lazer'],
#  ['moveis_escritorio'],
#  ['informatica_acessorios'],
#  ['relogios_presentes'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['utilidades_domesticas', 'informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['relogios_presentes', 'beleza_saude'],
#  ['informatica_acessorios'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao'],
#  ['ferramentas_jardim', 'eletronicos'],
#  ['casa_construcao', 'moveis_decoracao'],
#  ['beleza_saude', 'esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['ferramentas_jardim'],
#  ['informatica_acessorios', 'telefonia'],
#  ['construcao_ferramentas_jardim', 'cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['fashion_bolsas_e_acessorios'],
#  ['moveis_decoracao'],
#  ['ferramentas_jardim'],
#  ['esporte_lazer'],
#  ['informatica_acessorios'],
#  ['cool_stuff', 'bebes'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['beleza_saude'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho', 'ferramentas_jardim'],
#  ['esporte_lazer'],
#  ['artigos_de_natal'],
#  ['informatica_acessorios'],
#  ['esporte_lazer'],
#  ['moveis_decoracao', 'construcao_ferramentas_iluminacao'],
#  ['relogios_presentes'],
#  ['relogios_presentes'],
#  ['moveis_decoracao', 'cool_stuff'],
#  ['pet_shop'],
#  ['moveis_decoracao'],
#  ['relogios_presentes', 'automotivo'],
#  ['ferramentas_jardim'],
#  ['informatica_acessorios'],
#  ['alimentos'],
#  ['brinquedos'],
#  ['industria_comercio_e_negocios'],
#  ['relogios_presentes', 'instrumentos_musicais'],
#  ['livros_interesse_geral'],
#  ['moveis_decoracao'],
#  ['moveis_decoracao'],
#  ['papelaria'],
#  ['cama_mesa_banho'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['utilidades_domesticas', 'construcao_ferramentas_construcao'],
#  ['pet_shop'],
#  ['papelaria'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['automotivo'],
#  ['bebes'],
#  ['automotivo'],
#  ['telefonia'],
#  ['perfumaria'],
#  ['informatica_acessorios'],
#  ['moveis_decoracao', 'tablets_impressao_imagem'],
#  ['beleza_saude'],
#  ['cama_mesa_banho'],
#  ['construcao_ferramentas_iluminacao'],
#  ['moveis_decoracao', 'bebes'],
#  ['moveis_sala'],
#  ['cool_stuff', 'brinquedos'],
#  ['beleza_saude'],
#  ['esporte_lazer'],
#  ['informatica_acessorios'],
#  ['perfumaria'],
#  ['informatica_acessorios'],
#  ['cama_mesa_banho'],
#  ['esporte_lazer'],
#  ['esporte_lazer'],
#  ['eletronicos'],
#  ['fashion_bolsas_e_acessorios'],
#  ['utilidades_domesticas'],
#  ['moveis_decoracao'],
#  ['cool_stuff', 'fashion_underwear_e_moda_praia'],
#  ['fashion_bolsas_e_acessorios'],
#  ['moveis_decoracao', 'market_place'],
#  ['malas_acessorios'],
#  ['fashion_calcados'],
#  ['utilidades_domesticas'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['papelaria', 'moveis_decoracao'],
#  ['esporte_lazer'],
#  ['brinquedos', 'fashion_bolsas_e_acessorios'],
#  ['esporte_lazer'],
#  ['alimentos_bebidas'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho', 'moveis_decoracao'],
#  ['beleza_saude'],
#  ['moveis_decoracao', 'eletronicos'],
#  ['beleza_saude'],
#  ['informatica_acessorios'],
#  ['brinquedos', 'cool_stuff'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho', 'perfumaria'],
#  ['beleza_saude'],
#  ['telefonia'],
#  ['informatica_acessorios'],
#  ['beleza_saude'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['beleza_saude', 'telefonia'],
#  ['fashion_bolsas_e_acessorios'],
#  ['esporte_lazer'],
#  ['cama_mesa_banho'],
#  ['perfumaria'],
#  ['papelaria', 'relogios_presentes'],
#  ['moveis_decoracao'],
#  ['relogios_presentes'],
#  ['pet_shop'],
#  ['cama_mesa_banho', 'casa_conforto'],
#  ['informatica_acessorios'],
#  ['relogios_presentes'],
#  ['informatica_acessorios'],
#  ['eletronicos'],
#  ['ferramentas_jardim'],
#  ['moveis_decoracao', 'ferramentas_jardim'],
#  ['fashion_bolsas_e_acessorios'],
#  ['cama_mesa_banho'],
#  ['cama_mesa_banho'],
#  ['moveis_decoracao'],
#  ['esporte_lazer'],
#  ['utilidades_domesticas'],
#  ['cama_mesa_banho'],
#  ...]

# %% [markdown]
# Obtida a lista de compras por consumidor, agora estudamos somente aqueles que são recorrentes, isso é, possuem mais de uma compra, de modo que eles se tornem mais estatisticamente relevantes

# %%
recurrent_list = [(i, x) for i, x in enumerate(sales_list) if len(x) > 1]
recurrent_list
# Out:
# [(2, ['brinquedos', 'instrumentos_musicais']),
#  (5, ['eletronicos', 'informatica_acessorios']),
#  (6, ['moveis_sala', 'cama_mesa_banho']),
#  (13, ['cool_stuff', 'malas_acessorios']),
#  (24, ['flores', 'moveis_decoracao']),
#  (25, ['esporte_lazer', 'eletronicos']),
#  (26, ['bebes', 'moveis_decoracao']),
#  (32, ['eletrodomesticos', 'cama_mesa_banho']),
#  (39, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (42, ['automotivo', 'ferramentas_jardim']),
#  (43, ['instrumentos_musicais', 'brinquedos']),
#  (45, ['alimentos', 'esporte_lazer']),
#  (46, ['beleza_saude', 'moveis_escritorio']),
#  (48, ['construcao_ferramentas_iluminacao', 'moveis_decoracao']),
#  (52, ['brinquedos', 'instrumentos_musicais']),
#  (55, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (81, ['cama_mesa_banho', 'cool_stuff']),
#  (95, ['informatica_acessorios', 'consoles_games']),
#  (102, ['esporte_lazer', 'relogios_presentes']),
#  (105, ['moveis_sala', 'cama_mesa_banho']),
#  (113, ['informatica_acessorios', 'dvds_blu_ray']),
#  (114, ['beleza_saude', 'bebes']),
#  (125, ['telefonia_fixa', 'utilidades_domesticas']),
#  (126, ['cama_mesa_banho', 'beleza_saude']),
#  (133, ['moveis_decoracao', 'cama_mesa_banho']),
#  (135, ['bebes', 'esporte_lazer']),
#  (138, ['eletronicos', 'telefonia']),
#  (140, ['utilidades_domesticas', 'moveis_decoracao']),
#  (141, ['bebes', 'utilidades_domesticas']),
#  (147, ['utilidades_domesticas', 'moveis_sala']),
#  (155, ['perfumaria', 'esporte_lazer']),
#  (163, ['cama_mesa_banho', 'casa_conforto']),
#  (164, ['construcao_ferramentas_construcao', 'utilidades_domesticas']),
#  (169, ['beleza_saude', 'eletroportateis']),
#  (178, ['bebidas', 'telefonia', 'automotivo']),
#  (194, ['brinquedos', 'cama_mesa_banho']),
#  (200, ['brinquedos', 'papelaria']),
#  (205, ['cama_mesa_banho', 'ferramentas_jardim']),
#  (207, ['bebes', 'fashion_calcados']),
#  (209, ['utilidades_domesticas', 'cool_stuff']),
#  (210, ['relogios_presentes', 'audio']),
#  (220, ['moveis_decoracao', 'utilidades_domesticas']),
#  (224, ['cama_mesa_banho', 'moveis_decoracao']),
#  (240, ['bebes', 'utilidades_domesticas']),
#  (242, ['cama_mesa_banho', 'bebes']),
#  (245, ['esporte_lazer', 'eletroportateis']),
#  (250, ['perfumaria', 'moveis_decoracao']),
#  (251, ['telefonia', 'informatica_acessorios']),
#  (252, ['beleza_saude', 'perfumaria']),
#  (255, ['esporte_lazer', 'brinquedos']),
#  (266, ['relogios_presentes', 'ferramentas_jardim']),
#  (275, ['fashion_bolsas_e_acessorios', 'esporte_lazer']),
#  (285, ['eletrodomesticos', 'cama_mesa_banho']),
#  (300, ['perfumaria', 'climatizacao']),
#  (302, ['relogios_presentes', 'cama_mesa_banho']),
#  (306, ['moveis_decoracao', 'cama_mesa_banho']),
#  (314, ['telefonia', 'cine_foto', 'cool_stuff']),
#  (330, ['moveis_decoracao', 'papelaria']),
#  (331, ['consoles_games', 'esporte_lazer']),
#  (335, ['eletrodomesticos', 'utilidades_domesticas']),
#  (345, ['papelaria', 'ferramentas_jardim']),
#  (349, ['moveis_decoracao', 'industria_comercio_e_negocios']),
#  (354, ['perfumaria', 'malas_acessorios', 'moveis_decoracao']),
#  (355, ['consoles_games', 'utilidades_domesticas']),
#  (369, ['bebes', 'cool_stuff']),
#  (370, ['audio', 'relogios_presentes']),
#  (373, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (379, ['utilidades_domesticas', 'papelaria']),
#  (381, ['esporte_lazer', 'beleza_saude']),
#  (384, ['cool_stuff', 'ferramentas_jardim']),
#  (391, ['esporte_lazer', 'moveis_decoracao']),
#  (393, ['utilidades_domesticas', 'esporte_lazer']),
#  (398, ['alimentos', 'perfumaria']),
#  (402, ['utilidades_domesticas', 'esporte_lazer']),
#  (411, ['moveis_decoracao', 'perfumaria']),
#  (412, ['bebes', 'cama_mesa_banho']),
#  (415, ['utilidades_domesticas', 'eletroportateis']),
#  (419, ['cama_mesa_banho', 'moveis_sala']),
#  (439, ['industria_comercio_e_negocios', 'moveis_decoracao']),
#  (444, ['fashion_bolsas_e_acessorios', 'brinquedos']),
#  (446, ['cama_mesa_banho', 'brinquedos']),
#  (451, ['ferramentas_jardim', 'utilidades_domesticas']),
#  (457, ['relogios_presentes', 'moveis_decoracao']),
#  (462, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (464, ['cool_stuff', 'fashion_bolsas_e_acessorios']),
#  (465, ['esporte_lazer', 'construcao_ferramentas_construcao']),
#  (468, ['industria_comercio_e_negocios', 'beleza_saude']),
#  (469, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (477, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (488, ['brinquedos', 'informatica_acessorios']),
#  (492, ['moveis_cozinha_area_de_servico_jantar_e_jardim', 'moveis_decoracao']),
#  (494, ['perfumaria', 'brinquedos']),
#  (499, ['cool_stuff', 'consoles_games']),
#  (511, ['eletronicos', 'fashion_bolsas_e_acessorios']),
#  (513, ['artes', 'ferramentas_jardim']),
#  (517, ['cama_mesa_banho', 'cool_stuff']),
#  (518, ['pet_shop', 'casa_construcao']),
#  (521, ['esporte_lazer', 'consoles_games']),
#  (522, ['moveis_decoracao', 'bebes']),
#  (529, ['brinquedos', 'esporte_lazer']),
#  (537, ['esporte_lazer', 'beleza_saude']),
#  (549, ['moveis_decoracao', 'casa_construcao']),
#  (550, ['ferramentas_jardim', 'esporte_lazer']),
#  (557, ['automotivo', 'consoles_games']),
#  (565, ['esporte_lazer', 'beleza_saude']),
#  (567, ['cama_mesa_banho', 'moveis_decoracao']),
#  (572, ['moveis_decoracao', 'casa_conforto']),
#  (579, ['papelaria', 'casa_construcao']),
#  (584, ['moveis_decoracao', 'construcao_ferramentas_construcao']),
#  (588, ['beleza_saude', 'utilidades_domesticas']),
#  (590, ['moveis_sala', 'brinquedos']),
#  (596, ['esporte_lazer', 'telefonia', 'fashion_bolsas_e_acessorios']),
#  (597, ['ferramentas_jardim', 'bebes', 'esporte_lazer']),
#  (600, ['informatica_acessorios', 'malas_acessorios']),
#  (601, ['beleza_saude', 'cool_stuff']),
#  (611, ['eletroportateis', 'utilidades_domesticas']),
#  (615, ['cama_mesa_banho', 'moveis_decoracao']),
#  (616, ['relogios_presentes', 'casa_conforto']),
#  (622, ['casa_conforto', 'moveis_decoracao']),
#  (623, ['utilidades_domesticas', 'perfumaria']),
#  (626, ['artes', 'cool_stuff']),
#  (627, ['brinquedos', 'consoles_games']),
#  (628, ['relogios_presentes', 'livros_interesse_geral']),
#  (632, ['beleza_saude', 'cool_stuff']),
#  (635, ['malas_acessorios', 'telefonia']),
#  (637, ['informatica_acessorios', 'ferramentas_jardim']),
#  (638, ['casa_construcao', 'ferramentas_jardim']),
#  (641, ['cama_mesa_banho', 'bebidas']),
#  (643, ['alimentos', 'esporte_lazer']),
#  (645, ['beleza_saude', 'alimentos']),
#  (654, ['automotivo', 'beleza_saude']),
#  (665, ['brinquedos', 'cool_stuff']),
#  (666, ['bebes', 'cama_mesa_banho', 'fashion_bolsas_e_acessorios']),
#  (677, ['utilidades_domesticas', 'automotivo']),
#  (692, ['eletronicos', 'moveis_decoracao']),
#  (711, ['cama_mesa_banho', 'malas_acessorios']),
#  (720, ['esporte_lazer', 'construcao_ferramentas_ferramentas']),
#  (722, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (726, ['esporte_lazer', 'alimentos_bebidas']),
#  (729, ['casa_construcao', 'esporte_lazer']),
#  (734, ['moveis_decoracao', 'brinquedos']),
#  (740, ['brinquedos', 'construcao_ferramentas_construcao']),
#  (742, ['esporte_lazer', 'telefonia']),
#  (743, ['telefonia', 'telefonia_fixa']),
#  (744, ['eletronicos', 'automotivo']),
#  (746, ['cama_mesa_banho', 'moveis_decoracao']),
#  (747, ['cool_stuff', 'pc_gamer', 'pet_shop']),
#  (756, ['esporte_lazer', 'bebes']),
#  (767, ['informatica_acessorios', 'moveis_decoracao']),
#  (778, ['beleza_saude', 'utilidades_domesticas']),
#  (784, ['cama_mesa_banho', 'informatica_acessorios']),
#  (793, ['construcao_ferramentas_iluminacao', 'esporte_lazer']),
#  (800, ['moveis_sala', 'bebes', 'moveis_decoracao']),
#  (806, ['pet_shop', 'fashion_bolsas_e_acessorios', 'moveis_quarto']),
#  (808, ['moveis_decoracao', 'pet_shop']),
#  (825, ['moveis_decoracao', 'bebes']),
#  (833, ['moveis_decoracao', 'fashion_roupa_masculina']),
#  (835, ['fashion_bolsas_e_acessorios', 'malas_acessorios']),
#  (836, ['relogios_presentes', 'construcao_ferramentas_construcao']),
#  (838, ['ferramentas_jardim', 'utilidades_domesticas']),
#  (841, ['casa_conforto', 'cama_mesa_banho']),
#  (843, ['construcao_ferramentas_iluminacao', 'ferramentas_jardim']),
#  (862, ['esporte_lazer', 'relogios_presentes']),
#  (869, ['utilidades_domesticas', 'informatica_acessorios']),
#  (871, ['relogios_presentes', 'beleza_saude']),
#  (875, ['ferramentas_jardim', 'eletronicos']),
#  (876, ['casa_construcao', 'moveis_decoracao']),
#  (877, ['beleza_saude', 'esporte_lazer']),
#  (880, ['informatica_acessorios', 'telefonia']),
#  (881, ['construcao_ferramentas_jardim', 'cama_mesa_banho']),
#  (888, ['cool_stuff', 'bebes']),
#  (893, ['cama_mesa_banho', 'ferramentas_jardim']),
#  (898, ['moveis_decoracao', 'construcao_ferramentas_iluminacao']),
#  (901, ['moveis_decoracao', 'cool_stuff']),
#  (904, ['relogios_presentes', 'automotivo']),
#  (910, ['relogios_presentes', 'instrumentos_musicais']),
#  (919, ['utilidades_domesticas', 'construcao_ferramentas_construcao']),
#  (930, ['moveis_decoracao', 'tablets_impressao_imagem']),
#  (934, ['moveis_decoracao', 'bebes']),
#  (936, ['cool_stuff', 'brinquedos']),
#  (949, ['cool_stuff', 'fashion_underwear_e_moda_praia']),
#  (951, ['moveis_decoracao', 'market_place']),
#  (957, ['papelaria', 'moveis_decoracao']),
#  (959, ['brinquedos', 'fashion_bolsas_e_acessorios']),
#  (963, ['cama_mesa_banho', 'moveis_decoracao']),
#  (965, ['moveis_decoracao', 'eletronicos']),
#  (968, ['brinquedos', 'cool_stuff']),
#  (970, ['cama_mesa_banho', 'perfumaria']),
#  (977, ['beleza_saude', 'telefonia']),
#  (982, ['papelaria', 'relogios_presentes']),
#  (986, ['cama_mesa_banho', 'casa_conforto']),
#  (992, ['moveis_decoracao', 'ferramentas_jardim']),
#  (1005, ['informatica_acessorios', 'moveis_decoracao']),
#  (1006, ['casa_construcao', 'construcao_ferramentas_iluminacao']),
#  (1007, ['instrumentos_musicais', 'brinquedos']),
#  (1008, ['perfumaria', 'alimentos']),
#  (1011, ['brinquedos', 'cama_mesa_banho']),
#  (1014, ['beleza_saude', 'brinquedos']),
#  (1034, ['pet_shop', 'cama_mesa_banho']),
#  (1046, ['cama_mesa_banho', 'esporte_lazer']),
#  (1049, ['beleza_saude', 'automotivo']),
#  (1051,
#   ['utilidades_domesticas', 'cama_mesa_banho', 'fashion_bolsas_e_acessorios']),
#  (1054, ['beleza_saude', 'moveis_decoracao']),
#  (1057, ['papelaria', 'fashion_bolsas_e_acessorios']),
#  (1063, ['moveis_decoracao', 'beleza_saude']),
#  (1064, ['relogios_presentes', 'moveis_decoracao']),
#  (1070, ['eletronicos', 'beleza_saude']),
#  (1074, ['automotivo', 'ferramentas_jardim']),
#  (1078, ['fashion_calcados', 'esporte_lazer']),
#  (1079, ['fashion_roupa_masculina', 'esporte_lazer']),
#  (1090, ['beleza_saude', 'ferramentas_jardim']),
#  (1093, ['informatica_acessorios', 'telefonia']),
#  (1098, ['moveis_decoracao', 'esporte_lazer']),
#  (1099, ['utilidades_domesticas', 'bebes']),
#  (1101, ['eletroportateis', 'cool_stuff']),
#  (1102, ['papelaria', 'brinquedos']),
#  (1105, ['moveis_decoracao', 'relogios_presentes']),
#  (1106, ['fashion_bolsas_e_acessorios', 'brinquedos']),
#  (1109, ['pet_shop', 'construcao_ferramentas_jardim']),
#  (1110, ['informatica_acessorios', 'esporte_lazer']),
#  (1112, ['relogios_presentes', 'utilidades_domesticas']),
#  (1114, ['cama_mesa_banho', 'moveis_decoracao']),
#  (1117, ['relogios_presentes', 'telefonia']),
#  (1122, ['papelaria', 'utilidades_domesticas']),
#  (1123, ['cool_stuff', 'brinquedos']),
#  (1126, ['casa_construcao', 'moveis_decoracao']),
#  (1128, ['utilidades_domesticas', 'informatica_acessorios']),
#  (1130, ['pet_shop', 'esporte_lazer']),
#  (1138, ['moveis_decoracao', 'moveis_escritorio']),
#  (1144, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (1155, ['informatica_acessorios', 'alimentos']),
#  (1159, ['pet_shop', 'moveis_decoracao']),
#  (1169, ['casa_construcao', 'utilidades_domesticas', 'moveis_decoracao']),
#  (1177, ['moveis_decoracao', 'cama_mesa_banho']),
#  (1180, ['telefonia', 'utilidades_domesticas']),
#  (1185,
#   ['beleza_saude',
#    'moveis_decoracao',
#    'perfumaria',
#    'papelaria',
#    'utilidades_domesticas']),
#  (1186,
#   ['cama_mesa_banho', 'utilidades_domesticas', 'informatica_acessorios']),
#  (1188, ['perfumaria', 'moveis_decoracao']),
#  (1190, ['moveis_decoracao', 'cama_mesa_banho']),
#  (1193, ['casa_construcao', 'moveis_sala']),
#  (1229, ['utilidades_domesticas', 'perfumaria']),
#  (1231, ['telefonia', 'informatica_acessorios']),
#  (1233, ['informatica_acessorios', 'bebidas']),
#  (1239, ['cama_mesa_banho', 'market_place', 'utilidades_domesticas']),
#  (1245, ['brinquedos', 'relogios_presentes']),
#  (1246, ['cama_mesa_banho', 'beleza_saude', 'fashion_calcados']),
#  (1251, ['ferramentas_jardim', 'automotivo']),
#  (1255, ['automotivo', 'cama_mesa_banho']),
#  (1265, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (1270, ['cama_mesa_banho', 'moveis_decoracao']),
#  (1272, ['perfumaria', 'pet_shop']),
#  (1276, ['informatica_acessorios', 'papelaria']),
#  (1277, ['artigos_de_natal', 'casa_construcao']),
#  (1295, ['ferramentas_jardim', 'cama_mesa_banho']),
#  (1307, ['eletrodomesticos', 'ferramentas_jardim']),
#  (1310, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (1318, ['perfumaria', 'moveis_decoracao']),
#  (1321, ['cama_mesa_banho', 'cool_stuff']),
#  (1324, ['cama_mesa_banho', 'casa_conforto']),
#  (1334, ['bebes', 'moveis_decoracao']),
#  (1343, ['relogios_presentes', 'moveis_escritorio']),
#  (1345, ['esporte_lazer', 'utilidades_domesticas']),
#  (1353, ['eletronicos', 'cama_mesa_banho']),
#  (1354, ['beleza_saude', 'moveis_decoracao']),
#  (1362, ['moveis_decoracao', 'utilidades_domesticas']),
#  (1366, ['utilidades_domesticas', 'casa_construcao']),
#  (1372, ['cool_stuff', 'cama_mesa_banho']),
#  (1374, ['telefonia', 'relogios_presentes']),
#  (1379, ['utilidades_domesticas', 'esporte_lazer']),
#  (1380, ['pet_shop', 'ferramentas_jardim']),
#  (1384, ['consoles_games', 'automotivo']),
#  (1391, ['cool_stuff', 'esporte_lazer']),
#  (1397, ['bebes', 'cool_stuff']),
#  (1401, ['moveis_quarto', 'bebes']),
#  (1403, ['telefonia', 'bebes']),
#  (1414, ['utilidades_domesticas', 'esporte_lazer']),
#  (1429, ['moveis_decoracao', 'informatica_acessorios']),
#  (1432, ['ferramentas_jardim', 'fashion_roupa_feminina']),
#  (1433, ['esporte_lazer', 'cama_mesa_banho']),
#  (1439, ['cama_mesa_banho', 'bebes']),
#  (1448, ['perfumaria', 'utilidades_domesticas']),
#  (1454, ['relogios_presentes', 'fashion_calcados']),
#  (1456, ['cama_mesa_banho', 'ferramentas_jardim']),
#  (1459, ['cama_mesa_banho', 'moveis_cozinha_area_de_servico_jantar_e_jardim']),
#  (1461, ['cool_stuff', 'moveis_decoracao']),
#  (1469, ['cama_mesa_banho', 'pet_shop']),
#  (1477, ['utilidades_domesticas', 'moveis_decoracao']),
#  (1479, ['livros_tecnicos', 'beleza_saude']),
#  (1481, ['automotivo', 'ferramentas_jardim']),
#  (1497, ['telefonia', 'automotivo']),
#  (1500, ['cama_mesa_banho', 'pet_shop']),
#  (1505, ['bebes', 'cama_mesa_banho']),
#  (1520, ['informatica_acessorios', 'moveis_decoracao']),
#  (1539, ['relogios_presentes', 'fashion_bolsas_e_acessorios']),
#  (1549, ['fashion_bolsas_e_acessorios', 'brinquedos']),
#  (1550, ['cama_mesa_banho', 'informatica_acessorios']),
#  (1557, ['moveis_decoracao', 'papelaria']),
#  (1560, ['ferramentas_jardim', 'casa_construcao']),
#  (1568, ['perfumaria', 'beleza_saude']),
#  (1577, ['perfumaria', 'relogios_presentes']),
#  (1584, ['malas_acessorios', 'perfumaria']),
#  (1585, ['beleza_saude', 'perfumaria']),
#  (1589, ['cool_stuff', 'beleza_saude']),
#  (1591, ['moveis_escritorio', 'moveis_sala']),
#  (1592, ['utilidades_domesticas', 'consoles_games']),
#  (1601, ['cama_mesa_banho', 'moveis_decoracao']),
#  (1604, ['brinquedos', 'bebes']),
#  (1605, ['cama_mesa_banho', 'moveis_decoracao']),
#  (1611, ['bebes', 'moveis_decoracao']),
#  (1614, ['cama_mesa_banho', 'automotivo']),
#  (1619,
#   ['fashion_bolsas_e_acessorios', 'utilidades_domesticas', 'market_place']),
#  (1626, ['cama_mesa_banho', 'moveis_decoracao']),
#  (1645, ['utilidades_domesticas', 'industria_comercio_e_negocios']),
#  (1653, ['esporte_lazer', 'automotivo']),
#  (1663, ['moveis_decoracao', 'esporte_lazer']),
#  (1667, ['informatica_acessorios', 'cama_mesa_banho']),
#  (1669, ['moveis_decoracao', 'ferramentas_jardim']),
#  (1672, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (1676, ['beleza_saude', 'eletronicos']),
#  (1681, ['perfumaria', 'automotivo']),
#  (1686, ['utilidades_domesticas', 'informatica_acessorios']),
#  (1695, ['relogios_presentes', 'moveis_decoracao']),
#  (1697, ['cama_mesa_banho', 'moveis_decoracao']),
#  (1711, ['cool_stuff', 'cama_mesa_banho']),
#  (1715, ['malas_acessorios', 'esporte_lazer']),
#  (1721, ['fashion_roupa_masculina', 'cama_mesa_banho']),
#  (1724, ['climatizacao', 'moveis_escritorio']),
#  (1725, ['relogios_presentes', 'telefonia']),
#  (1726, ['cama_mesa_banho', 'moveis_escritorio']),
#  (1738, ['beleza_saude', 'alimentos']),
#  (1739, ['esporte_lazer', 'fashion_bolsas_e_acessorios']),
#  (1740, ['informatica_acessorios', 'beleza_saude']),
#  (1746, ['cama_mesa_banho', 'moveis_decoracao']),
#  (1753, ['moveis_decoracao', 'casa_conforto']),
#  (1754, ['relogios_presentes', 'fashion_bolsas_e_acessorios']),
#  (1757, ['moveis_escritorio', 'utilidades_domesticas']),
#  (1758, ['beleza_saude', 'cama_mesa_banho']),
#  (1762, ['cama_mesa_banho', 'casa_conforto']),
#  (1768, ['brinquedos', 'esporte_lazer']),
#  (1777, ['pet_shop', 'utilidades_domesticas']),
#  (1779, ['automotivo', 'telefonia']),
#  (1793, ['cama_mesa_banho', 'informatica_acessorios']),
#  (1799, ['beleza_saude', 'papelaria']),
#  (1800, ['moveis_decoracao', 'bebes']),
#  (1811, ['brinquedos', 'papelaria']),
#  (1813, ['automotivo', 'esporte_lazer']),
#  (1815, ['cama_mesa_banho', 'perfumaria']),
#  (1820, ['telefonia', 'cama_mesa_banho']),
#  (1822, ['casa_conforto', 'cama_mesa_banho']),
#  (1827, ['utilidades_domesticas', 'cama_mesa_banho', 'bebes']),
#  (1841, ['cama_mesa_banho', 'consoles_games']),
#  (1853, ['informatica_acessorios', 'telefonia']),
#  (1854, ['casa_conforto', 'eletroportateis']),
#  (1859, ['beleza_saude', 'informatica_acessorios']),
#  (1861, ['instrumentos_musicais', 'cama_mesa_banho']),
#  (1863, ['informatica_acessorios', 'cama_mesa_banho']),
#  (1865, ['utilidades_domesticas', 'relogios_presentes']),
#  (1866, ['relogios_presentes', 'beleza_saude']),
#  (1869, ['telefonia', 'cama_mesa_banho']),
#  (1879, ['beleza_saude', 'esporte_lazer']),
#  (1880, ['moveis_decoracao', 'bebes']),
#  (1883, ['esporte_lazer', 'beleza_saude']),
#  (1896, ['eletronicos', 'brinquedos']),
#  (1898, ['papelaria', 'brinquedos']),
#  (1899, ['perfumaria', 'cama_mesa_banho']),
#  (1910, ['telefonia', 'informatica_acessorios']),
#  (1925, ['relogios_presentes', 'fashion_bolsas_e_acessorios']),
#  (1927, ['bebes', 'cool_stuff']),
#  (1930, ['malas_acessorios', 'papelaria']),
#  (1933, ['beleza_saude', 'bebidas']),
#  (1935, ['papelaria', 'beleza_saude']),
#  (1936, ['livros_interesse_geral', 'bebes']),
#  (1944, ['malas_acessorios', 'telefonia']),
#  (1946, ['ferramentas_jardim', 'malas_acessorios']),
#  (1963, ['construcao_ferramentas_seguranca', 'bebes']),
#  (1968, ['bebidas', 'telefonia']),
#  (1971, ['bebes', 'moveis_decoracao']),
#  (1973, ['utilidades_domesticas', 'pet_shop']),
#  (1989, ['eletronicos', 'informatica_acessorios']),
#  (1990, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2007, ['papelaria', 'relogios_presentes']),
#  (2009, ['brinquedos', 'consoles_games']),
#  (2013, ['moveis_decoracao', 'relogios_presentes']),
#  (2032, ['cama_mesa_banho', 'informatica_acessorios']),
#  (2039, ['eletroportateis', 'utilidades_domesticas']),
#  (2042, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2043, ['utilidades_domesticas', 'esporte_lazer']),
#  (2051, ['fashion_calcados', 'bebes']),
#  (2061, ['ferramentas_jardim', 'moveis_sala']),
#  (2064, ['perfumaria', 'cool_stuff']),
#  (2066, ['bebes', 'cool_stuff']),
#  (2073, ['moveis_sala', 'moveis_decoracao']),
#  (2075, ['ferramentas_jardim', 'utilidades_domesticas']),
#  (2076, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2086, ['cama_mesa_banho', 'casa_conforto']),
#  (2089, ['moveis_decoracao', 'construcao_ferramentas_iluminacao']),
#  (2098, ['moveis_decoracao', 'construcao_ferramentas_iluminacao']),
#  (2101, ['automotivo', 'esporte_lazer']),
#  (2104, ['beleza_saude', 'esporte_lazer']),
#  (2108, ['cama_mesa_banho', 'informatica_acessorios']),
#  (2111,
#   ['utilidades_domesticas', 'moveis_cozinha_area_de_servico_jantar_e_jardim']),
#  (2119, ['relogios_presentes', 'ferramentas_jardim']),
#  (2123, ['relogios_presentes', 'papelaria']),
#  (2129, ['cama_mesa_banho', 'casa_conforto']),
#  (2139,
#   ['relogios_presentes',
#    'moveis_cozinha_area_de_servico_jantar_e_jardim',
#    'cama_mesa_banho']),
#  (2142, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2143, ['perfumaria', 'esporte_lazer']),
#  (2159, ['cool_stuff', 'beleza_saude']),
#  (2165, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2166, ['ferramentas_jardim', 'informatica_acessorios']),
#  (2174, ['esporte_lazer', 'utilidades_domesticas']),
#  (2182, ['brinquedos', 'beleza_saude']),
#  (2194, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (2195, ['moveis_decoracao', 'bebes']),
#  (2201, ['relogios_presentes', 'papelaria']),
#  (2204, ['telefonia', 'construcao_ferramentas_construcao']),
#  (2210, ['informatica_acessorios', 'utilidades_domesticas']),
#  (2214, ['informatica_acessorios', 'sinalizacao_e_seguranca']),
#  (2215, ['utilidades_domesticas', 'informatica_acessorios']),
#  (2221, ['relogios_presentes', 'brinquedos']),
#  (2222, ['casa_construcao', 'informatica_acessorios']),
#  (2236, ['cool_stuff', 'utilidades_domesticas']),
#  (2242, ['relogios_presentes', 'cama_mesa_banho']),
#  (2252, ['construcao_ferramentas_jardim', 'automotivo']),
#  (2264, ['construcao_ferramentas_construcao', 'utilidades_domesticas']),
#  (2265, ['bebes', 'relogios_presentes']),
#  (2268, ['beleza_saude', 'cama_mesa_banho']),
#  (2270, ['ferramentas_jardim', 'moveis_decoracao']),
#  (2279, ['utilidades_domesticas', 'beleza_saude', 'alimentos_bebidas']),
#  (2281, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2291, ['esporte_lazer', 'ferramentas_jardim']),
#  (2309, ['beleza_saude', 'telefonia']),
#  (2315, ['informatica_acessorios', 'climatizacao']),
#  (2317, ['moveis_sala', 'esporte_lazer']),
#  (2327, ['malas_acessorios', 'papelaria']),
#  (2328, ['beleza_saude', 'cool_stuff']),
#  (2331, ['esporte_lazer', 'beleza_saude']),
#  (2332,
#   ['esporte_lazer',
#    'alimentos_bebidas',
#    'beleza_saude',
#    'malas_acessorios',
#    'relogios_presentes']),
#  (2337, ['papelaria', 'fashion_bolsas_e_acessorios']),
#  (2338, ['brinquedos', 'telefonia']),
#  (2346, ['moveis_sala', 'consoles_games']),
#  (2352, ['bebes', 'cool_stuff']),
#  (2359, ['moveis_sala', 'bebes']),
#  (2373, ['bebes', 'cama_mesa_banho']),
#  (2378, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2382, ['beleza_saude', 'esporte_lazer']),
#  (2384, ['informatica_acessorios', 'cama_mesa_banho']),
#  (2385, ['ferramentas_jardim', 'utilidades_domesticas']),
#  (2391, ['cama_mesa_banho', 'bebes']),
#  (2395, ['esporte_lazer', 'cama_mesa_banho']),
#  (2399, ['climatizacao', 'eletrodomesticos']),
#  (2404, ['esporte_lazer', 'cama_mesa_banho']),
#  (2408, ['automotivo', 'cool_stuff']),
#  (2412, ['eletronicos', 'malas_acessorios']),
#  (2415, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2421, ['fashion_bolsas_e_acessorios', 'beleza_saude']),
#  (2429, ['esporte_lazer', 'moveis_decoracao']),
#  (2434, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2462, ['fashion_bolsas_e_acessorios', 'cama_mesa_banho']),
#  (2467, ['esporte_lazer', 'moveis_decoracao', 'bebes']),
#  (2472, ['ferramentas_jardim', 'construcao_ferramentas_construcao']),
#  (2474, ['beleza_saude', 'malas_acessorios']),
#  (2480, ['cama_mesa_banho', 'fashion_calcados']),
#  (2482, ['moveis_decoracao', 'beleza_saude']),
#  (2486, ['livros_tecnicos', 'musica']),
#  (2488, ['telefonia', 'fashion_bolsas_e_acessorios']),
#  (2513, ['esporte_lazer', 'beleza_saude']),
#  (2528, ['moveis_decoracao', 'perfumaria']),
#  (2534, ['cama_mesa_banho', 'bebes']),
#  (2537, ['relogios_presentes', 'brinquedos']),
#  (2539, ['moveis_decoracao', 'esporte_lazer']),
#  (2548, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2549, ['cama_mesa_banho', 'casa_conforto']),
#  (2550, ['telefonia', 'relogios_presentes']),
#  (2553, ['esporte_lazer', 'utilidades_domesticas']),
#  (2572, ['papelaria', 'relogios_presentes']),
#  (2573, ['esporte_lazer', 'relogios_presentes']),
#  (2581, ['utilidades_domesticas', 'informatica_acessorios']),
#  (2582, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2587, ['papelaria', 'perfumaria']),
#  (2594, ['construcao_ferramentas_seguranca', 'informatica_acessorios']),
#  (2599, ['instrumentos_musicais', 'eletronicos']),
#  (2608, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2611, ['moveis_decoracao', 'casa_construcao']),
#  (2621, ['artes_e_artesanato', 'brinquedos']),
#  (2625, ['esporte_lazer', 'malas_acessorios']),
#  (2630, ['utilidades_domesticas', 'consoles_games']),
#  (2642, ['eletrodomesticos', 'eletronicos']),
#  (2643, ['moveis_decoracao', 'brinquedos']),
#  (2651, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2652, ['tablets_impressao_imagem', 'bebes']),
#  (2653, ['moveis_decoracao', 'casa_construcao']),
#  (2655, ['automotivo', 'moveis_decoracao']),
#  (2661, ['automotivo', 'brinquedos']),
#  (2669, ['cool_stuff', 'telefonia']),
#  (2675, ['relogios_presentes', 'esporte_lazer']),
#  (2678, ['utilidades_domesticas', 'moveis_decoracao']),
#  (2680,
#   ['casa_construcao',
#    'moveis_decoracao',
#    'cama_mesa_banho',
#    'informatica_acessorios',
#    'utilidades_domesticas']),
#  (2683, ['cool_stuff', 'perfumaria', 'automotivo']),
#  (2691, ['utilidades_domesticas', 'beleza_saude']),
#  (2700, ['automotivo', 'papelaria', 'brinquedos']),
#  (2708, ['cama_mesa_banho', 'bebes']),
#  (2714, ['construcao_ferramentas_construcao', 'pet_shop']),
#  (2717, ['beleza_saude', 'perfumaria']),
#  (2718, ['relogios_presentes', 'telefonia']),
#  (2729, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2734, ['bebes', 'brinquedos']),
#  (2737, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2738, ['utilidades_domesticas', 'alimentos_bebidas']),
#  (2748, ['relogios_presentes', 'brinquedos']),
#  (2751, ['moveis_decoracao', 'perfumaria']),
#  (2762, ['ferramentas_jardim', 'utilidades_domesticas']),
#  (2772, ['esporte_lazer', 'informatica_acessorios']),
#  (2773, ['moveis_decoracao', 'utilidades_domesticas']),
#  (2775, ['bebes', 'beleza_saude']),
#  (2781, ['moveis_colchao_e_estofado', 'esporte_lazer']),
#  (2793, ['moveis_decoracao', 'moveis_sala']),
#  (2799, ['construcao_ferramentas_construcao', 'casa_construcao']),
#  (2807, ['cama_mesa_banho', 'brinquedos']),
#  (2819, ['cama_mesa_banho', 'pet_shop']),
#  (2821, ['musica', 'livros_tecnicos']),
#  (2830, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2834, ['brinquedos', 'esporte_lazer']),
#  (2840, ['artigos_de_natal', 'cama_mesa_banho']),
#  (2849, ['telefonia', 'automotivo']),
#  (2850, ['moveis_decoracao', 'cama_mesa_banho']),
#  (2856, ['cama_mesa_banho', 'papelaria']),
#  (2857, ['telefonia', 'informatica_acessorios']),
#  (2862, ['esporte_lazer', 'beleza_saude']),
#  (2868, ['ferramentas_jardim', 'casa_construcao']),
#  (2872, ['esporte_lazer', 'telefonia']),
#  (2875,
#   ['ferramentas_jardim',
#    'cama_mesa_banho',
#    'construcao_ferramentas_iluminacao']),
#  (2876, ['brinquedos', 'cama_mesa_banho']),
#  (2889, ['eletronicos', 'brinquedos']),
#  (2890, ['cool_stuff', 'bebes']),
#  (2898, ['cool_stuff', 'cama_mesa_banho']),
#  (2904, ['cool_stuff', 'informatica_acessorios', 'casa_construcao']),
#  (2910, ['utilidades_domesticas', 'papelaria']),
#  (2925, ['ferramentas_jardim', 'moveis_decoracao']),
#  (2937, ['bebidas', 'beleza_saude']),
#  (2938, ['ferramentas_jardim', 'moveis_decoracao']),
#  (2940, ['eletronicos', 'esporte_lazer']),
#  (2941, ['informatica_acessorios', 'cama_mesa_banho']),
#  (2944, ['cama_mesa_banho', 'moveis_decoracao']),
#  (2957, ['cama_mesa_banho', 'perfumaria']),
#  (2958, ['beleza_saude', 'esporte_lazer']),
#  (2980, ['bebes', 'cama_mesa_banho']),
#  (2989, ['moveis_decoracao', 'bebidas']),
#  (2990, ['perfumaria', 'beleza_saude']),
#  (2995, ['cama_mesa_banho', 'moveis_escritorio']),
#  (3004, ['utilidades_domesticas', 'ferramentas_jardim']),
#  (3005, ['malas_acessorios', 'fashion_bolsas_e_acessorios']),
#  (3007, ['moveis_decoracao', 'cama_mesa_banho']),
#  (3011, ['utilidades_domesticas', 'moveis_decoracao']),
#  (3015, ['utilidades_domesticas', 'relogios_presentes']),
#  (3016, ['esporte_lazer', 'beleza_saude']),
#  (3019, ['fashion_bolsas_e_acessorios', 'utilidades_domesticas']),
#  (3024, ['relogios_presentes', 'telefonia']),
#  (3033, ['cama_mesa_banho', 'utilidades_domesticas', 'moveis_decoracao']),
#  (3038, ['fashion_calcados', 'utilidades_domesticas']),
#  (3039, ['esporte_lazer', 'casa_construcao']),
#  (3040, ['eletronicos', 'informatica_acessorios']),
#  (3041, ['market_place', 'fashion_bolsas_e_acessorios']),
#  (3043, ['consoles_games', 'beleza_saude']),
#  (3047, ['esporte_lazer', 'relogios_presentes']),
#  (3058, ['telefonia', 'eletronicos']),
#  (3061, ['esporte_lazer', 'automotivo']),
#  (3064,
#   ['tablets_impressao_imagem',
#    'cool_stuff',
#    'beleza_saude',
#    'automotivo',
#    'cama_mesa_banho']),
#  (3066, ['esporte_lazer', 'bebidas']),
#  (3079, ['construcao_ferramentas_iluminacao', 'moveis_decoracao']),
#  (3083, ['relogios_presentes', 'eletrodomesticos']),
#  (3084, ['fashion_bolsas_e_acessorios', 'beleza_saude']),
#  (3089, ['esporte_lazer', 'utilidades_domesticas']),
#  (3094, ['construcao_ferramentas_iluminacao', 'esporte_lazer']),
#  (3103, ['telefonia', 'relogios_presentes']),
#  (3111, ['cama_mesa_banho', 'casa_conforto']),
#  (3116, ['relogios_presentes', 'instrumentos_musicais']),
#  (3133, ['moveis_decoracao', 'cama_mesa_banho']),
#  (3134, ['moveis_colchao_e_estofado', 'bebes']),
#  (3142, ['cama_mesa_banho', 'construcao_ferramentas_seguranca']),
#  (3144, ['ferramentas_jardim', 'automotivo']),
#  (3153, ['automotivo', 'telefonia']),
#  (3157, ['beleza_saude', 'ferramentas_jardim']),
#  (3159, ['esporte_lazer', 'telefonia_fixa']),
#  (3160, ['moveis_decoracao', 'cama_mesa_banho']),
#  (3161, ['automotivo', 'cool_stuff', 'cama_mesa_banho']),
#  (3164, ['moveis_decoracao', 'relogios_presentes']),
#  (3166, ['eletronicos', 'casa_conforto']),
#  (3171, ['moveis_decoracao', 'utilidades_domesticas']),
#  (3202, ['utilidades_domesticas', 'moveis_decoracao']),
#  (3207, ['relogios_presentes', 'automotivo']),
#  (3214, ['cama_mesa_banho', 'moveis_decoracao']),
#  (3228, ['ferramentas_jardim', 'artes_e_artesanato']),
#  (3231, ['cool_stuff', 'bebes']),
#  (3240, ['cama_mesa_banho', 'moveis_decoracao', 'ferramentas_jardim']),
#  (3258, ['cama_mesa_banho', 'construcao_ferramentas_seguranca']),
#  (3270, ['esporte_lazer', 'telefonia']),
#  (3272, ['moveis_decoracao', 'bebes']),
#  (3279, ['casa_conforto_2', 'instrumentos_musicais']),
#  (3282, ['informatica_acessorios', 'beleza_saude']),
#  (3285, ['esporte_lazer', 'ferramentas_jardim']),
#  (3290, ['bebes', 'cama_mesa_banho']),
#  (3293, ['ferramentas_jardim', 'eletronicos']),
#  (3294, ['moveis_decoracao', 'ferramentas_jardim']),
#  (3300, ['moveis_decoracao', 'brinquedos']),
#  (3309, ['telefonia', 'moveis_sala']),
#  (3317, ['eletrodomesticos', 'moveis_decoracao', 'utilidades_domesticas']),
#  (3324, ['brinquedos', 'papelaria']),
#  (3330, ['moveis_decoracao', 'artes']),
#  (3331, ['relogios_presentes', 'utilidades_domesticas']),
#  (3333, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (3340, ['pet_shop', 'moveis_decoracao']),
#  (3344, ['cama_mesa_banho', 'perfumaria']),
#  (3347,
#   ['ferramentas_jardim', 'automotivo', 'consoles_games', 'alimentos_bebidas']),
#  (3350, ['market_place', 'livros_interesse_geral']),
#  (3371, ['moveis_decoracao', 'cama_mesa_banho']),
#  (3375, ['pet_shop', 'brinquedos']),
#  (3381, ['construcao_ferramentas_jardim', 'cama_mesa_banho']),
#  (3383, ['malas_acessorios', 'informatica_acessorios']),
#  (3385, ['esporte_lazer', 'moveis_decoracao']),
#  (3387, ['fashion_bolsas_e_acessorios', 'fashion_underwear_e_moda_praia']),
#  (3394, ['moveis_decoracao', 'utilidades_domesticas']),
#  (3396, ['cama_mesa_banho', 'perfumaria']),
#  (3413, ['ferramentas_jardim', 'telefonia']),
#  (3422, ['ferramentas_jardim', 'casa_construcao']),
#  (3423, ['moveis_decoracao', 'utilidades_domesticas']),
#  (3432, ['beleza_saude', 'brinquedos']),
#  (3440, ['moveis_decoracao', 'cool_stuff']),
#  (3445, ['perfumaria', 'beleza_saude']),
#  (3446, ['informatica_acessorios', 'casa_construcao']),
#  (3458, ['perfumaria', 'esporte_lazer']),
#  (3460, ['fashion_bolsas_e_acessorios', 'beleza_saude']),
#  (3467, ['cama_mesa_banho', 'casa_conforto']),
#  (3476, ['market_place', 'informatica_acessorios']),
#  (3477, ['cool_stuff', 'moveis_sala']),
#  (3481, ['agro_industria_e_comercio', 'moveis_decoracao']),
#  (3484, ['beleza_saude', 'cama_mesa_banho']),
#  (3485, ['cama_mesa_banho', 'moveis_decoracao']),
#  (3486, ['malas_acessorios', 'eletroportateis']),
#  (3493, ['moveis_decoracao', 'cama_mesa_banho']),
#  (3502, ['brinquedos', 'utilidades_domesticas']),
#  (3503, ['utilidades_domesticas', 'moveis_decoracao']),
#  (3507, ['automotivo', 'utilidades_domesticas']),
#  (3514, ['bebes', 'brinquedos']),
#  (3516, ['moveis_decoracao', 'utilidades_domesticas']),
#  (3527, ['eletronicos', 'telefonia']),
#  (3532, ['construcao_ferramentas_construcao', 'brinquedos']),
#  (3536, ['telefonia', 'informatica_acessorios']),
#  (3561, ['ferramentas_jardim', 'perfumaria']),
#  (3564,
#   ['cama_mesa_banho',
#    'moveis_cozinha_area_de_servico_jantar_e_jardim',
#    'automotivo']),
#  (3569, ['moveis_escritorio', 'beleza_saude']),
#  (3571, ['telefonia_fixa', 'informatica_acessorios']),
#  (3575, ['cama_mesa_banho', 'casa_conforto']),
#  (3579, ['esporte_lazer', 'relogios_presentes']),
#  (3581, ['informatica_acessorios', 'cama_mesa_banho', 'esporte_lazer']),
#  (3590, ['cool_stuff', 'audio']),
#  (3591, ['beleza_saude', 'esporte_lazer']),
#  (3594,
#   ['relogios_presentes', 'fashion_bolsas_e_acessorios', 'artigos_de_natal']),
#  (3602, ['casa_conforto', 'cama_mesa_banho']),
#  (3605, ['beleza_saude', 'informatica_acessorios']),
#  (3607, ['fashion_calcados', 'relogios_presentes']),
#  (3620, ['cama_mesa_banho', 'moveis_decoracao']),
#  (3630, ['eletronicos', 'cama_mesa_banho']),
#  (3633, ['esporte_lazer', 'bebidas']),
#  (3635, ['telefonia', 'cool_stuff']),
#  (3636, ['moveis_decoracao', 'cama_mesa_banho']),
#  (3643, ['papelaria', 'telefonia']),
#  (3659, ['bebes', 'utilidades_domesticas']),
#  (3660, ['cool_stuff', 'cama_mesa_banho']),
#  (3666, ['casa_conforto', 'moveis_decoracao']),
#  (3669, ['eletroportateis', 'informatica_acessorios']),
#  (3695, ['moveis_decoracao', 'cama_mesa_banho', 'artes_e_artesanato']),
#  (3701, ['cool_stuff', 'informatica_acessorios']),
#  (3706, ['perfumaria', 'alimentos']),
#  (3718, ['utilidades_domesticas', 'ferramentas_jardim']),
#  (3724, ['perfumaria', 'fashion_bolsas_e_acessorios']),
#  (3738, ['informatica_acessorios', 'la_cuisine']),
#  (3746, ['relogios_presentes', 'esporte_lazer']),
#  (3750, ['automotivo', 'informatica_acessorios']),
#  (3757, ['automotivo', 'bebidas']),
#  (3760, ['brinquedos', 'moveis_decoracao']),
#  (3761, ['relogios_presentes', 'esporte_lazer']),
#  (3775, ['telefonia', 'utilidades_domesticas']),
#  (3783, ['brinquedos', 'telefonia']),
#  (3791, ['tablets_impressao_imagem', 'informatica_acessorios']),
#  (3797, ['telefonia', 'pet_shop']),
#  (3809, ['bebes', 'cama_mesa_banho']),
#  (3815, ['malas_acessorios', 'construcao_ferramentas_seguranca']),
#  (3816, ['fashion_bolsas_e_acessorios', 'bebes']),
#  (3821, ['casa_conforto', 'brinquedos']),
#  (3830, ['cama_mesa_banho', 'casa_conforto']),
#  (3836, ['brinquedos', 'bebes']),
#  (3849, ['artes', 'utilidades_domesticas']),
#  (3850, ['cool_stuff', 'moveis_decoracao']),
#  (3859, ['telefonia', 'automotivo']),
#  (3864, ['moveis_decoracao', 'cama_mesa_banho']),
#  (3874, ['relogios_presentes', 'esporte_lazer']),
#  (3877, ['utilidades_domesticas', 'brinquedos']),
#  (3878, ['ferramentas_jardim', 'eletronicos']),
#  (3879, ['moveis_decoracao', 'utilidades_domesticas']),
#  (3882, ['moveis_decoracao', 'utilidades_domesticas', 'cama_mesa_banho']),
#  (3886, ['esporte_lazer', 'beleza_saude']),
#  (3889, ['brinquedos', 'fashion_calcados']),
#  (3892, ['beleza_saude', 'ferramentas_jardim']),
#  (3903, ['moveis_decoracao', 'utilidades_domesticas']),
#  (3904, ['fashion_bolsas_e_acessorios', 'moveis_decoracao']),
#  (3913, ['beleza_saude', 'automotivo']),
#  (3916, ['brinquedos', 'bebes']),
#  (3919, ['relogios_presentes', 'utilidades_domesticas']),
#  (3920, ['utilidades_domesticas', 'bebidas']),
#  (3924, ['moveis_decoracao', 'utilidades_domesticas']),
#  (3934, ['ferramentas_jardim', 'eletrodomesticos']),
#  (3938, ['utilidades_domesticas', 'construcao_ferramentas_construcao']),
#  (3939, ['ferramentas_jardim', 'la_cuisine']),
#  (3946, ['esporte_lazer', 'moveis_decoracao']),
#  (3948, ['telefonia', 'cool_stuff']),
#  (3950, ['ferramentas_jardim', 'construcao_ferramentas_seguranca']),
#  (3960, ['ferramentas_jardim', 'moveis_decoracao']),
#  (3961, ['cama_mesa_banho', 'moveis_decoracao']),
#  (3974, ['cool_stuff', 'bebes']),
#  (3975, ['bebes', 'brinquedos']),
#  (3978, ['relogios_presentes', 'moveis_decoracao', 'cama_mesa_banho']),
#  (3986, ['telefonia_fixa', 'cool_stuff']),
#  (4012, ['ferramentas_jardim', 'beleza_saude']),
#  (4018, ['utilidades_domesticas', 'esporte_lazer']),
#  (4020, ['cama_mesa_banho', 'eletronicos']),
#  (4022, ['cool_stuff', 'cama_mesa_banho']),
#  (4030, ['alimentos', 'relogios_presentes', 'audio']),
#  (4040, ['telefonia', 'bebes']),
#  (4051, ['market_place', 'livros_interesse_geral']),
#  (4052, ['cama_mesa_banho', 'relogios_presentes']),
#  (4061, ['eletronicos', 'esporte_lazer']),
#  (4063, ['papelaria', 'ferramentas_jardim']),
#  (4069, ['fashion_bolsas_e_acessorios', 'moveis_decoracao']),
#  (4070, ['perfumaria', 'beleza_saude']),
#  (4076, ['esporte_lazer', 'bebidas']),
#  (4077, ['pet_shop', 'informatica_acessorios']),
#  (4088, ['moveis_decoracao', 'casa_construcao']),
#  (4089, ['cama_mesa_banho', 'moveis_decoracao']),
#  (4095, ['relogios_presentes', 'pet_shop']),
#  (4100, ['utilidades_domesticas', 'eletroportateis']),
#  (4104, ['pet_shop', 'malas_acessorios']),
#  (4105, ['casa_conforto', 'cama_mesa_banho']),
#  (4112, ['casa_construcao', 'moveis_decoracao']),
#  (4115, ['utilidades_domesticas', 'bebes']),
#  (4117, ['esporte_lazer', 'relogios_presentes']),
#  (4119, ['telefonia', 'malas_acessorios']),
#  (4126, ['construcao_ferramentas_construcao', 'ferramentas_jardim']),
#  (4127, ['moveis_sala', 'moveis_escritorio']),
#  (4131, ['cama_mesa_banho', 'moveis_decoracao']),
#  (4141, ['casa_construcao', 'moveis_decoracao']),
#  (4145, ['cama_mesa_banho', 'moveis_decoracao']),
#  (4146, ['cama_mesa_banho', 'climatizacao']),
#  (4158, ['moveis_cozinha_area_de_servico_jantar_e_jardim', 'brinquedos']),
#  (4163, ['brinquedos', 'bebes', 'beleza_saude']),
#  (4164, ['consoles_games', 'pet_shop']),
#  (4166, ['esporte_lazer', 'utilidades_domesticas']),
#  (4174, ['bebes', 'musica', 'fashion_bolsas_e_acessorios']),
#  (4187, ['informatica_acessorios', 'cama_mesa_banho']),
#  (4190, ['moveis_decoracao', 'beleza_saude']),
#  (4197, ['fashion_bolsas_e_acessorios', 'informatica_acessorios']),
#  (4208, ['beleza_saude', 'cool_stuff']),
#  (4209, ['utilidades_domesticas', 'moveis_decoracao', 'automotivo']),
#  (4213, ['esporte_lazer', 'moveis_decoracao']),
#  (4216, ['beleza_saude', 'esporte_lazer']),
#  (4220, ['beleza_saude', 'utilidades_domesticas']),
#  (4225, ['moveis_decoracao', 'moveis_sala']),
#  (4227, ['esporte_lazer', 'moveis_decoracao']),
#  (4230, ['ferramentas_jardim', 'pet_shop']),
#  (4238, ['utilidades_domesticas', 'informatica_acessorios']),
#  (4240, ['brinquedos', 'bebes']),
#  (4241, ['beleza_saude', 'papelaria']),
#  (4245,
#   ['moveis_sala',
#    'cama_mesa_banho',
#    'construcao_ferramentas_construcao',
#    'moveis_decoracao']),
#  (4260, ['bebes', 'informatica_acessorios']),
#  (4264, ['livros_interesse_geral', 'fashion_bolsas_e_acessorios']),
#  (4268, ['bebidas', 'utilidades_domesticas']),
#  (4289, ['fashion_bolsas_e_acessorios', 'utilidades_domesticas']),
#  (4293, ['ferramentas_jardim', 'moveis_decoracao']),
#  (4298, ['cama_mesa_banho', 'moveis_decoracao']),
#  (4316, ['beleza_saude', 'informatica_acessorios']),
#  (4320, ['ferramentas_jardim', 'cama_mesa_banho']),
#  (4323, ['perfumaria', 'beleza_saude']),
#  (4324, ['telefonia', 'bebidas']),
#  (4327, ['ferramentas_jardim', 'utilidades_domesticas']),
#  (4331, ['brinquedos', 'pet_shop']),
#  (4335, ['moveis_escritorio', 'moveis_decoracao']),
#  (4336, ['eletroportateis', 'utilidades_domesticas']),
#  (4339, ['cama_mesa_banho', 'pet_shop']),
#  (4345, ['informatica_acessorios', 'papelaria']),
#  (4350, ['perfumaria', 'beleza_saude']),
#  (4355, ['esporte_lazer', 'perfumaria']),
#  (4359, ['perfumaria', 'moveis_decoracao']),
#  (4373, ['cama_mesa_banho', 'casa_conforto']),
#  (4375, ['esporte_lazer', 'construcao_ferramentas_construcao']),
#  (4388, ['relogios_presentes', 'moveis_decoracao']),
#  (4402, ['moveis_decoracao', 'utilidades_domesticas']),
#  (4415, ['ferramentas_jardim', 'moveis_decoracao']),
#  (4430, ['pet_shop', 'automotivo']),
#  (4435, ['beleza_saude', 'moveis_decoracao']),
#  (4436, ['automotivo', 'beleza_saude']),
#  (4437, ['eletronicos', 'cama_mesa_banho']),
#  (4440, ['perfumaria', 'telefonia']),
#  (4442, ['eletronicos', 'perfumaria']),
#  (4449, ['esporte_lazer', 'bebidas']),
#  (4464, ['cool_stuff', 'relogios_presentes']),
#  (4467, ['papelaria', 'beleza_saude']),
#  (4481, ['utilidades_domesticas', 'moveis_decoracao']),
#  (4483, ['moveis_decoracao', 'utilidades_domesticas']),
#  (4489, ['cama_mesa_banho', 'bebes']),
#  (4492, ['automotivo', 'beleza_saude']),
#  (4500, ['esporte_lazer', 'brinquedos']),
#  (4503, ['cama_mesa_banho', 'moveis_decoracao']),
#  (4514, ['ferramentas_jardim', 'livros_interesse_geral']),
#  (4516, ['esporte_lazer', 'perfumaria']),
#  (4517, ['casa_conforto', 'cama_mesa_banho']),
#  (4520, ['sinalizacao_e_seguranca', 'automotivo']),
#  (4544, ['bebes', 'utilidades_domesticas', 'cama_mesa_banho']),
#  (4553, ['esporte_lazer', 'industria_comercio_e_negocios']),
#  (4555, ['cama_mesa_banho', 'bebes']),
#  (4556, ['esporte_lazer', 'informatica_acessorios']),
#  (4561, ['casa_construcao', 'construcao_ferramentas_seguranca']),
#  (4563, ['moveis_decoracao', 'construcao_ferramentas_iluminacao']),
#  (4576, ['moveis_decoracao', 'cama_mesa_banho']),
#  (4581, ['informatica_acessorios', 'automotivo']),
#  (4592, ['relogios_presentes', 'moveis_decoracao']),
#  (4596, ['construcao_ferramentas_iluminacao', 'moveis_decoracao']),
#  (4605, ['moveis_decoracao', 'informatica_acessorios']),
#  (4606, ['moveis_decoracao', 'cama_mesa_banho']),
#  (4610, ['papelaria', 'beleza_saude']),
#  (4614, ['fashion_bolsas_e_acessorios', 'moveis_decoracao']),
#  (4615, ['cama_mesa_banho', 'casa_conforto']),
#  (4617, ['pet_shop', 'moveis_decoracao', 'esporte_lazer']),
#  (4629, ['relogios_presentes', 'perfumaria']),
#  (4630, ['cama_mesa_banho', 'casa_conforto']),
#  (4632, ['casa_conforto', 'esporte_lazer', 'beleza_saude']),
#  (4634, ['moveis_decoracao', 'moveis_sala']),
#  (4635, ['construcao_ferramentas_construcao', 'cama_mesa_banho']),
#  (4652, ['cool_stuff', 'consoles_games']),
#  (4661, ['ferramentas_jardim', 'utilidades_domesticas']),
#  (4671, ['eletronicos', 'cool_stuff']),
#  (4692, ['cama_mesa_banho', 'fashion_bolsas_e_acessorios']),
#  (4693, ['cool_stuff', 'moveis_decoracao']),
#  (4696, ['papelaria', 'perfumaria']),
#  (4699, ['brinquedos', 'esporte_lazer']),
#  (4706, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (4711, ['moveis_sala', 'moveis_decoracao']),
#  (4718, ['moveis_decoracao', 'relogios_presentes', 'utilidades_domesticas']),
#  (4726, ['eletronicos', 'telefonia', 'audio']),
#  (4727, ['moveis_decoracao', 'cama_mesa_banho']),
#  (4736, ['cool_stuff', 'perfumaria']),
#  (4741, ['relogios_presentes', 'eletronicos']),
#  (4747, ['brinquedos', 'cool_stuff']),
#  (4748, ['beleza_saude', 'esporte_lazer']),
#  (4751, ['utilidades_domesticas', 'moveis_decoracao']),
#  (4759, ['papelaria', 'beleza_saude']),
#  (4762, ['cama_mesa_banho', 'moveis_decoracao']),
#  (4765, ['informatica_acessorios', 'audio']),
#  (4777, ['sinalizacao_e_seguranca', 'bebes']),
#  (4786, ['utilidades_domesticas', 'casa_conforto']),
#  (4791, ['informatica_acessorios', 'musica']),
#  (4795, ['beleza_saude', 'esporte_lazer']),
#  (4806, ['esporte_lazer', 'casa_construcao']),
#  (4816, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (4820, ['papelaria', 'relogios_presentes']),
#  (4822, ['moveis_escritorio', 'cama_mesa_banho']),
#  (4838, ['telefonia', 'informatica_acessorios']),
#  (4845, ['moveis_decoracao', 'relogios_presentes']),
#  (4848, ['cama_mesa_banho', 'esporte_lazer']),
#  (4850, ['relogios_presentes', 'utilidades_domesticas']),
#  (4853, ['esporte_lazer', 'ferramentas_jardim']),
#  (4860, ['perfumaria', 'esporte_lazer']),
#  (4862, ['beleza_saude', 'telefonia']),
#  (4873, ['brinquedos', 'cama_mesa_banho']),
#  (4891, ['ferramentas_jardim', 'casa_construcao']),
#  (4894, ['informatica_acessorios', 'eletronicos']),
#  (4903, ['cama_mesa_banho', 'beleza_saude']),
#  (4904, ['moveis_escritorio', 'informatica_acessorios']),
#  (4909, ['utilidades_domesticas', 'perfumaria']),
#  (4914, ['cama_mesa_banho', 'pet_shop', 'fashion_bolsas_e_acessorios']),
#  (4915, ['ferramentas_jardim', 'informatica_acessorios']),
#  (4916, ['automotivo', 'bebes']),
#  (4917, ['brinquedos', 'papelaria']),
#  (4918, ['moveis_decoracao', 'casa_conforto']),
#  (4925, ['instrumentos_musicais', 'brinquedos']),
#  (4942, ['brinquedos', 'relogios_presentes']),
#  (4944, ['beleza_saude', 'fashion_underwear_e_moda_praia']),
#  (4955, ['moveis_decoracao', 'eletroportateis']),
#  (4957, ['construcao_ferramentas_iluminacao', 'moveis_decoracao']),
#  (4958, ['automotivo', 'cama_mesa_banho']),
#  (4959, ['utilidades_domesticas', 'malas_acessorios']),
#  (4964, ['brinquedos', 'esporte_lazer']),
#  (4970, ['relogios_presentes', 'audio']),
#  (4973, ['perfumaria', 'esporte_lazer']),
#  (4975, ['cama_mesa_banho', 'informatica_acessorios']),
#  (4998,
#   ['moveis_quarto',
#    'construcao_ferramentas_construcao',
#    'climatizacao',
#    'ferramentas_jardim',
#    'eletrodomesticos']),
#  (5006, ['casa_construcao', 'telefonia']),
#  (5026, ['perfumaria', 'fashion_bolsas_e_acessorios']),
#  (5027, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (5028, ['automotivo', 'moveis_escritorio']),
#  (5030, ['eletronicos', 'moveis_decoracao']),
#  (5033, ['eletroportateis', 'cama_mesa_banho']),
#  (5038, ['informatica_acessorios', 'automotivo']),
#  (5039, ['papelaria', 'perfumaria']),
#  (5040, ['moveis_decoracao', 'eletrodomesticos_2']),
#  (5044, ['moveis_decoracao', 'market_place']),
#  (5053, ['cama_mesa_banho', 'casa_conforto']),
#  (5062, ['malas_acessorios', 'bebes']),
#  (5063, ['ferramentas_jardim', 'esporte_lazer']),
#  (5067, ['moveis_decoracao', 'cama_mesa_banho', 'bebes']),
#  (5069, ['esporte_lazer', 'informatica_acessorios']),
#  (5074, ['papelaria', 'cama_mesa_banho']),
#  (5080, ['beleza_saude', 'eletronicos']),
#  (5085, ['cama_mesa_banho', 'moveis_decoracao']),
#  (5086, ['bebes', 'cama_mesa_banho']),
#  (5091, ['cama_mesa_banho', 'moveis_decoracao']),
#  (5100, ['esporte_lazer', 'utilidades_domesticas']),
#  (5101, ['brinquedos', 'bebes']),
#  (5117, ['cama_mesa_banho', 'perfumaria']),
#  (5125, ['eletronicos', 'cama_mesa_banho']),
#  (5126, ['beleza_saude', 'papelaria']),
#  (5130, ['moveis_decoracao', 'cama_mesa_banho']),
#  (5131, ['sinalizacao_e_seguranca', 'esporte_lazer', 'beleza_saude']),
#  (5135, ['cama_mesa_banho', 'automotivo']),
#  (5136, ['tablets_impressao_imagem', 'cool_stuff']),
#  (5137, ['cool_stuff', 'esporte_lazer']),
#  (5147, ['bebes', 'cama_mesa_banho']),
#  (5158, ['cool_stuff', 'papelaria']),
#  (5163, ['moveis_decoracao', 'relogios_presentes']),
#  (5166, ['cama_mesa_banho', 'esporte_lazer']),
#  (5174, ['moveis_decoracao', 'ferramentas_jardim']),
#  (5175, ['telefonia', 'automotivo']),
#  (5178, ['brinquedos', 'bebes']),
#  (5179, ['utilidades_domesticas', 'bebes', 'esporte_lazer', 'papelaria']),
#  (5181, ['beleza_saude', 'eletrodomesticos_2']),
#  (5188, ['cama_mesa_banho', 'casa_conforto']),
#  (5191, ['fashion_bolsas_e_acessorios', 'papelaria']),
#  (5192, ['fashion_bolsas_e_acessorios', 'esporte_lazer']),
#  (5194, ['telefonia', 'eletroportateis']),
#  (5196, ['cama_mesa_banho', 'beleza_saude']),
#  (5197, ['construcao_ferramentas_seguranca', 'informatica_acessorios']),
#  (5199, ['beleza_saude', 'telefonia']),
#  (5202, ['moveis_colchao_e_estofado', 'eletroportateis']),
#  (5204, ['casa_conforto_2', 'automotivo']),
#  (5217, ['cool_stuff', 'bebes']),
#  (5218, ['utilidades_domesticas', 'construcao_ferramentas_construcao']),
#  (5219, ['automotivo', 'beleza_saude']),
#  (5220, ['utilidades_domesticas', 'informatica_acessorios']),
#  (5221, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (5223, ['fashion_bolsas_e_acessorios', 'esporte_lazer']),
#  (5236, ['utilidades_domesticas', 'fashion_bolsas_e_acessorios']),
#  (5240, ['moveis_decoracao', 'cama_mesa_banho']),
#  (5244, ['relogios_presentes', 'automotivo']),
#  (5257, ['fashion_calcados', 'informatica_acessorios']),
#  (5262, ['informatica_acessorios', 'malas_acessorios']),
#  (5265, ['informatica_acessorios', 'ferramentas_jardim']),
#  (5271, ['automotivo', 'esporte_lazer']),
#  (5285, ['consoles_games', 'informatica_acessorios']),
#  (5298, ['beleza_saude', 'papelaria']),
#  (5305,
#   ['construcao_ferramentas_construcao',
#    'moveis_cozinha_area_de_servico_jantar_e_jardim']),
#  (5310, ['utilidades_domesticas', 'bebes']),
#  (5312, ['cama_mesa_banho', 'ferramentas_jardim']),
#  (5315, ['cama_mesa_banho', 'moveis_decoracao']),
#  (5324, ['utilidades_domesticas', 'cama_mesa_banho']),
#  (5329, ['beleza_saude', 'telefonia']),
#  (5334, ['beleza_saude', 'esporte_lazer']),
#  (5335, ['beleza_saude', 'moveis_decoracao']),
#  (5336, ['cama_mesa_banho', 'casa_conforto']),
#  (5338, ['moveis_decoracao', 'perfumaria']),
#  (5349, ['cama_mesa_banho', 'pet_shop']),
#  (5356, ['telefonia', 'beleza_saude']),
#  (5358, ['brinquedos', 'relogios_presentes']),
#  (5359, ['brinquedos', 'esporte_lazer']),
#  (5367, ['moveis_decoracao', 'utilidades_domesticas']),
#  (5369, ['eletrodomesticos', 'informatica_acessorios']),
#  (5375, ['papelaria', 'ferramentas_jardim']),
#  (5382, ['perfumaria', 'livros_importados']),
#  (5383, ['utilidades_domesticas', 'esporte_lazer']),
#  (5391, ['cama_mesa_banho', 'casa_conforto']),
#  (5395, ['fashion_bolsas_e_acessorios', 'brinquedos']),
#  (5396, ['cama_mesa_banho', 'utilidades_domesticas']),
#  (5400, ['cama_mesa_banho', 'moveis_decoracao']),
#  (5413, ['cama_mesa_banho', 'moveis_decoracao']),
#  (5416, ['brinquedos', 'cool_stuff']),
#  (5418, ['cama_mesa_banho', 'casa_conforto']),
#  (5419, ['relogios_presentes', 'moveis_decoracao']),
#  (5420, ['automotivo', 'moveis_decoracao']),
#  (5421, ['moveis_decoracao', 'utilidades_domesticas']),
#  (5423, ['ferramentas_jardim', 'informatica_acessorios']),
#  (5438, ['relogios_presentes', 'esporte_lazer']),
#  (5439, ['fashion_underwear_e_moda_praia', 'relogios_presentes']),
#  (5454, ['cool_stuff', 'bebes']),
#  (5455, ['esporte_lazer', 'beleza_saude']),
#  (5468, ['malas_acessorios', 'beleza_saude']),
#  (5478, ['perfumaria', 'market_place', 'cama_mesa_banho']),
#  (5480, ['relogios_presentes', 'informatica_acessorios']),
#  (5481, ['beleza_saude', 'cool_stuff']),
#  (5486, ['beleza_saude', 'esporte_lazer']),
#  (5488, ['eletronicos', 'alimentos']),
#  (5492, ['audio', 'beleza_saude']),
#  (5493, ['casa_construcao', 'moveis_decoracao']),
#  ...]

# %% [markdown]
# Criamos um *SparkContext* para acessarmos a biblioteca do *PySpark*, que possui as funcionalidades de **FPGrowth** que queremos analizar nesse estudo

# %%
spark = SparkSession.builder.master("local").appName("Word Count").getOrCreate()

# %% [markdown]
# A partir de então criamos de fato o nosso modelo de **FPGrowth**. É importante notarmos o hiperparâmetro *minSupport*, que determina qual a frequência mínima de ocorrência de um padrão para que ele seja considerado frequente. Nesse caso, ele foi configurado para 5%, isso é, qualquer padrão que apareça em ao menos 5% das compras é considerado estatisticamente relevante e portanto frequente

# %%
fp = FPGrowth(minSupport=0.01, minConfidence=0.15)

sdf = spark.createDataFrame(recurrent_list, ["id", "items"])
fpm = fp.fit(sdf)

# %%
result = fpm.freqItemsets.collect()
for fi in sorted(result, key=lambda x: x.freq, reverse=True):
    print(fi)
# Out:
# Row(items=['cama_mesa_banho'], freq=512)
# Row(items=['moveis_decoracao'], freq=477)
# Row(items=['utilidades_domesticas'], freq=290)
# Row(items=['esporte_lazer'], freq=274)
# Row(items=['beleza_saude'], freq=248)
# Row(items=['informatica_acessorios'], freq=190)
# Row(items=['ferramentas_jardim'], freq=184)
# Row(items=['brinquedos'], freq=167)
# Row(items=['relogios_presentes'], freq=161)
# Row(items=['bebes'], freq=160)
# Row(items=['cool_stuff'], freq=150)
# Row(items=['moveis_decoracao', 'cama_mesa_banho'], freq=149)
# Row(items=['automotivo'], freq=118)
# Row(items=['telefonia'], freq=117)
# Row(items=['perfumaria'], freq=114)
# Row(items=['fashion_bolsas_e_acessorios'], freq=111)
# Row(items=['papelaria'], freq=95)
# Row(items=['eletronicos'], freq=83)
# Row(items=['casa_conforto'], freq=73)
# Row(items=['pet_shop'], freq=67)
# Row(items=['utilidades_domesticas', 'cama_mesa_banho'], freq=59)
# Row(items=['utilidades_domesticas', 'moveis_decoracao'], freq=56)
# Row(items=['casa_conforto', 'cama_mesa_banho'], freq=54)
# Row(items=['casa_construcao'], freq=54)
# Row(items=['malas_acessorios'], freq=43)
# Row(items=['ferramentas_jardim', 'moveis_decoracao'], freq=42)
# Row(items=['moveis_escritorio'], freq=41)
# Row(items=['beleza_saude', 'esporte_lazer'], freq=39)
# Row(items=['construcao_ferramentas_construcao'], freq=38)
# Row(items=['moveis_sala'], freq=36)
# Row(items=['bebes', 'cama_mesa_banho'], freq=36)
# Row(items=['consoles_games'], freq=31)
# Row(items=['cool_stuff', 'bebes'], freq=28)
# Row(items=['beleza_saude', 'cama_mesa_banho'], freq=27)
# Row(items=['bebes', 'brinquedos'], freq=26)
# Row(items=['bebidas'], freq=25)
# Row(items=['construcao_ferramentas_iluminacao'], freq=24)
# Row(items=['perfumaria', 'beleza_saude'], freq=24)
# Row(items=['esporte_lazer', 'utilidades_domesticas'], freq=24)
# Row(items=['cool_stuff', 'cama_mesa_banho'], freq=23)
# Row(items=['eletrodomesticos'], freq=23)
# Row(items=['alimentos'], freq=22)
# Row(items=['eletroportateis'], freq=22)
# Row(items=['ferramentas_jardim', 'utilidades_domesticas'], freq=22)
# Row(items=['relogios_presentes', 'moveis_decoracao'], freq=21)
# Row(items=['esporte_lazer', 'moveis_decoracao'], freq=21)

# %% [markdown]
# É possível perceber que a maioria dos padrões possuem somente uma categoria, o que significa que grande parte das compras as possuem em comum. Notemos, porém, a presença de `['moveis_decoracao', 'cama_mesa_banho'], freq=149`, indicando uma alta frequência de compras conjuntas desses itens.

# %%
fpm.associationRules.show()
# Out:
# +--------------------+------------------+-------------------+------------------+
# |          antecedent|        consequent|         confidence|              lift|
# +--------------------+------------------+-------------------+------------------+
# |        [perfumaria]|    [beleza_saude]|0.21052631578947367|1.7393887945670627|
# |   [cama_mesa_banho]|[moveis_decoracao]|        0.291015625|  1.25008598663522|
# |             [bebes]|      [cool_stuff]|              0.175|            2.3905|
# |             [bebes]|      [brinquedos]|             0.1625|1.9937874251497005|
# |             [bebes]| [cama_mesa_banho]|              0.225|    0.900439453125|
# |[ferramentas_jardim]|[moveis_decoracao]|0.22826086956521738|0.9805168170631664|
# |     [casa_conforto]| [cama_mesa_banho]| 0.7397260273972602| 2.960348886986301|
# |[utilidades_domes...|[moveis_decoracao]|0.19310344827586207|0.8294946866189546|
# |[utilidades_domes...| [cama_mesa_banho]|0.20344827586206896|0.8141904633620689|
# |        [brinquedos]|           [bebes]|0.15568862275449102|1.9937874251497005|
# |  [moveis_decoracao]| [cama_mesa_banho]|0.31236897274633124|  1.25008598663522|
# |        [cool_stuff]|           [bebes]|0.18666666666666668|            2.3905|
# |        [cool_stuff]| [cama_mesa_banho]|0.15333333333333332|0.6136328124999999|
# |      [beleza_saude]|   [esporte_lazer]|0.15725806451612903|1.1759918766187898|
# +--------------------+------------------+-------------------+------------------+
